# %%
import torchvision

train = torchvision.datasets.Places365(root = "data/", split = 'val', small = True, download = True)
train
# Out:
# ...
# 100%|██████████| 67498496/67498496 [00:05<00:00, 11521361.63it/s]
# Extracting data/filelist_places365-standard.tar to data/
# ...
# 100%|██████████| 525158400/525158400 [00:34<00:00, 15254060.16it/s]
# Extracting data/val_256.tar to data/
# Dataset Places365
#     Number of datapoints: 36500
#     Root location: data/
#     Split: val
#     Small: True

# %%
# !git clone https://github.com/gabrielBarbutti/lama.git
# Out:
# Cloning into 'lama'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 69 (delta 36), reused 39 (delta 19), pack-reused 0
# Receiving objects: 100% (69/69), 27.17 KiB | 4.53 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# fatal: destination path 'lama' already exists and is not an empty directory.

# %%
# !ls
# Out:
# lama  sample_data
# data  lama  sample_data

# %%
import os
from pathlib import Path
import shutil
path = Path("data/val_256/")
# os.listdir(path)

# %%
from PIL import Image
import numpy
import matplotlib.pyplot as plt

x = plt.imread("data/val_256/Places365_val_00000259.jpg")   #all have (256,256) size
numpy.array(x).shape
# Out:
# (256, 256, 3)

# %%
from PIL import Image
import numpy
import matplotlib.pyplot as plt

count = 0
for i in os.listdir(path):
  img = plt.imread(path/i)
  if img.shape[-1] != 3:
    os.remove(path/i)
    count += 1

print(f"Deleted images with incorrect number of dims : {count}")
# Out:
# Deleted images with incorrect number of dims : 79

# %%
# import torch_xla.core.xla_model as xm
# device = xm.xla_device()
# device
# Out:
# device(type='xla', index=0)

# %%
# for training
# !python lama/main.py --experiment baseline --data_path data/val_256 #Path/of/your/dataset   [baseline, conv_change or wgan]
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Slicing : 9105
# ################ TRAINING STARTED ################
# Epoch 1 of 1
# ...

# %%
# # for testing with pretrained weights / trained
# !python lama/eval.py --experiment baseline \
#                 --data_path /data/val_256 #Path/of/your/testset \
#                 --checkpoint_path model_weights #Path/of/your/weight

# %%
# !pip install -q pytorch-fid

# %%
# !pip install -q lpips
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 64.2 MB/s eta 0:00:00

# %%
# !python lama/eval.py --experiment baseline --data_path data/val_256  --checkpoint_path model_weights/modelfinalepochs0batch28-05-2024_15h53.pth
# in eval.py comment out line 3 and last line
# also rename the weights file to 1 for ease
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
# Slicing : 9105
# ...

# %%
# 80%|██████████████████████████████████████████████████████████▏              | 907/1.14k [1:57:20<37:25, 9.68s/it, lpips=0.223, ssim=0.653, fid=6.71]
# 97%|█████████████████████████████████████████████████████████████████████  | 1.11k/1.14k [2:27:34<04:13, 7.94s/it, lpips=0.223, ssim=0.653, fid=6.72]

! pip install -q torchmetrics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 51.4 MB/s eta 0:00:00

# %%
from torchmetrics.image.fid import FrechetInceptionDistance

fid = FrechetInceptionDistance()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-8fe27447bb18> in <cell line: 3>()
#       1 from torchmetrics.image.fid import FrechetInceptionDistance
#       2
# ----> 3 fid = FrechetInceptionDistance()
#
# /usr/local/lib/python3.10/dist-packages/torchmetrics/image/fid.py in __init__(self, feature, reset_real_features, normalize, input_img_size, **kwargs)
#     314             num_features = feature
#     315             if not _TORCH_FIDELITY_AVAILABLE:
# --> 316                 raise ModuleNotFoundError(
#     317                     "FrechetInceptionDistance metric requires that `Torch-fidelity` is installed."
#     318                     " Either install as `pip install torchmetrics[image]` or `pip install torch-fidelity`."
#
# ...

# %%
from torchmetrics.utilities.imports import _MATPLOTLIB_AVAILABLE, _TORCH_FIDELITY_AVAILABLE

_TORCH_FIDELITY_AVAILABLE
# Out:
# DistributionNotFound: The 'torch_fidelity' distribution was not found and is required by the application. HINT: Try running `pip install -U 'torch_fidelity'`

# %%
# !pip install torch-fidelity

# %%
# !pip install  -q torchmetrics[image]

# %%
from torchmetrics.image import StructuralSimilarityIndexMeasure

preds = torch.rand([3, 3, 256, 256])
target = preds * 0.75
ssim = StructuralSimilarityIndexMeasure(data_range=1.0)
ssim(preds, target)

# %%
from torchmetrics.image.fid import FrechetInceptionDistance

fid = FrechetInceptionDistance(feature=64)

# generate two slightly overlapping image intensity distributions
imgs_dist1 = torch.randint(0, 200, (100, 3, 299, 299), dtype=torch.uint8)
imgs_dist2 = torch.randint(100, 255, (100, 3, 299, 299), dtype=torch.uint8)
fid.update(imgs_dist1, real=True)
fid.update(imgs_dist2, real=False)
fid.compute()

# %%
    # if image.shape[-1] != 3:
    #   return image

# %%
# import os
# from pathlib import Path
# import shutil

# new = "all_data/"
# path = Path("data/val_256/")

# path.mkdir(parents = True, exist_ok = True)

#For TEST-> ALREADY DONE NO NEED
# FOR TRAIN DATA
# for i in os.listdir(path):
#   for j in os.listdir(path/i):
#     gener = Path(path / i / j).glob('*.jpg')
#     for k in gener:
#       shutil.copy(k,new)

# %%
"""
Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
/usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
  warnings.warn(
/usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
  warnings.warn(msg)
Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
  0%|                                                                                                   | 0.00/9.11k [00:00<?, ?it/s, lpips=0, ssim=0]/content/lama/eval.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
  fid.update(torch.tensor(image_reconstructed, dtype=torch.uint8), real = False)
/content/lama/eval.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
  fid.update(torch.tensor(gt_image, dtype=torch.uint8), real = True)
  0%|                                                                                                       | 0.00/9.11k [00:01<?, ?it/s, lpips=0.754]
LPIPS : 0.7538749575614929 || SSIM : 0.03595248982310295 || FID : 12.539053916931152
  0%|                                                                                              | 1.00/9.11k [00:01<2:41:54, 1.07s/it, lpips=0.749]
LPIPS : 0.7489220798015594 || SSIM : 0.03535944223403931 || FID : 10.56195878982544
  0%|                                                                                              | 2.00/9.11k [00:02<2:28:07, 1.02it/s, lpips=0.752]
LPIPS : 0.751907209555308 || SSIM : 0.036227221290270485 || FID : 9.559391816457113
  0%|                                                                                               | 3.00/9.11k [00:03<2:23:05, 1.06it/s, lpips=0.75]
LPIPS : 0.7498181462287903 || SSIM : 0.03683430328965187 || FID : 8.754982113838196
  0%|                                                                                              | 4.00/9.11k [00:04<2:21:48, 1.07it/s, lpips=0.755]
LPIPS : 0.7552236557006836 || SSIM : 0.034760591387748715 || FID : 8.599324226379395
  0%|                                                                                              | 5.00/9.11k [00:05<2:24:42, 1.05it/s, lpips=0.754]
LPIPS : 0.7536657452583313 || SSIM : 0.03582232321302096 || FID : 8.379077037175497
  0%|▍                                                                                             | 38.0/9.11k [00:38<2:29:07, 1.01it/s, lpips=0.754]
LPIPS : 0.7543065211711786 || SSIM : 0.035377462657216266 || FID : 7.166142280285175
  0%|▍                                                                                             | 39.0/9.11k [00:39<2:34:07, 1.02s/it, lpips=0.754]
LPIPS : 0.7543673068284988 || SSIM : 0.035343259247019886 || FID : 7.170870900154114
  0%|▍                                                                                             | 40.0/9.11k [00:41<2:33:47, 1.02s/it, lpips=0.754]
LPIPS : 0.7544219581092276 || SSIM : 0.03544688738155656 || FID : 7.1713013532685075
  0%|▍                                                                                             | 41.0/9.11k [00:42<2:39:10, 1.05s/it, lpips=0.755]
LPIPS : 0.755035183259419 || SSIM : 0.0353884646846425 || FID : 7.177662894839332
  0%|▍                                                                                             | 42.0/9.11k [00:43<2:44:13, 1.09s/it, lpips=0.755]
LPIPS : 0.7550347890964774 || SSIM : 0.03538319472829963 || FID : 7.1813566961953805
  0%|▍                                                                                             | 43.0/9.11k [00:44<2:46:08, 1.10s/it, lpips=0.755]
LPIPS : 0.7552979371764443 || SSIM : 0.03535053798590194 || FID : 7.183668916875666
  0%|▍                                                                                             | 44.0/9.11k [00:45<2:46:57, 1.11s/it, lpips=0.755]
LPIPS : 0.7551901724603441 || SSIM : 0.0355499029573467 || FID : 7.182471243540446
  0%|▍                                                                                             | 45.0/9.11k [00:46<2:48:00, 1.11s/it, lpips=0.755]
LPIPS : 0.7549462888551794 || SSIM : 0.03557019053108018 || FID : 7.188434082528819
  1%|▍                                                                                             | 46.0/9.11k [00:47<2:51:50, 1.14s/it, lpips=0.755]
LPIPS : 0.755417951878081 || SSIM : 0.035336442093582866 || FID : 7.20726412915169
  1%|▍                                                                                             | 47.0/9.11k [00:49<2:51:13, 1.13s/it, lpips=0.755]
LPIPS : 0.755446112404267 || SSIM : 0.035343822984335325 || FID : 7.222874919573466
  1%|▍                                                                                             | 48.0/9.11k [00:50<2:53:20, 1.15s/it, lpips=0.756]
LPIPS : 0.7558854891329395 || SSIM : 0.0354500376828471 || FID : 7.238001181154835
  1%|▌                                                                                             | 49.0/9.11k [00:51<2:55:30, 1.16s/it, lpips=0.756]
LPIPS : 0.7563479816913605 || SSIM : 0.03533046502619982 || FID : 7.25721321105957
  1%|▌                                                                                             | 50.0/9.11k [00:52<2:52:26, 1.14s/it, lpips=0.757]
LPIPS : 0.7565971881735558 || SSIM : 0.03533503643291838 || FID : 7.274062624164656
  1%|▌                                                                                             | 51.0/9.11k [00:53<2:50:13, 1.13s/it, lpips=0.757]
LPIPS : 0.7569005603973682 || SSIM : 0.03528256066000232 || FID : 7.289976009955773
  1%|▌                                                                                             | 52.0/9.11k [00:54<2:50:14, 1.13s/it, lpips=0.757]
LPIPS : 0.7568696219966097 || SSIM : 0.03527562302660267 || FID : 7.3059112440864995
  1%|▌                                                                                             | 53.0/9.11k [00:55<2:52:05, 1.14s/it, lpips=0.757]
LPIPS : 0.7565634217527177 || SSIM : 0.03525546424228836 || FID : 7.320464593392831
  2%|█▋                                                                                             | 167/9.11k [05:00<7:33:16, 3.04s/it, lpips=0.757]
LPIPS : 0.7570221477321216 || SSIM : 0.03531913484801494 || FID : 7.9908268338158015
  2%|█▊                                                                                             | 168/9.11k [05:03<7:27:32, 3.00s/it, lpips=0.757]
LPIPS : 0.7569351566613779 || SSIM : 0.0353481140119966 || FID : 7.992626489266842
  2%|█▊                                                                                             | 169/9.11k [05:06<7:22:21, 2.97s/it, lpips=0.757]
LPIPS : 0.7568420115639182 || SSIM : 0.03534293554942398 || FID : 7.994431849086986
  2%|█▊                                                                                             | 170/9.11k [05:10<7:36:20, 3.06s/it, lpips=0.757]
LPIPS : 0.7568872428079795 || SSIM : 0.03534468571650006 || FID : 7.9961393925181605
  2%|█▊                                                                                             | 171/9.11k [05:13<7:44:35, 3.12s/it, lpips=0.757]
LPIPS : 0.7571404964424843 || SSIM : 0.03534820319564883 || FID : 7.997976596965346
  2%|█▊                                                                                             | 172/9.11k [05:16<7:51:31, 3.17s/it, lpips=0.757]
LPIPS : 0.7570628516935889 || SSIM : 0.03539440306065055 || FID : 7.999632201442829
  2%|█▊                                                                                             | 173/9.11k [05:19<7:56:51, 3.20s/it, lpips=0.757]
LPIPS : 0.7570824931407797 || SSIM : 0.03540839652006311 || FID : 8.001440634672669
  2%|█▊                                                                                             | 174/9.11k [05:23<7:57:11, 3.21s/it, lpips=0.757]
LPIPS : 0.7571532188143049 || SSIM : 0.035415965712496215 || FID : 8.003228896004813
  2%|█▊                                                                                             | 175/9.11k [05:26<8:03:07, 3.25s/it, lpips=0.757]
LPIPS : 0.7571812925690954 || SSIM : 0.03543415531219745 || FID : 8.005108042196794
  2%|█▊                                                                                             | 176/9.11k [05:29<8:08:46, 3.28s/it, lpips=0.757]
LPIPS : 0.7571330875326685 || SSIM : 0.03543475340778208 || FID : 8.006991542665299
  2%|█▊                                                                                             | 177/9.11k [05:32<8:02:12, 3.24s/it, lpips=0.757]
LPIPS : 0.7571780818901704 || SSIM : 0.03545078604869294 || FID : 8.008779381098373
  2%|█▊                                                                                             | 178/9.11k [05:35<7:58:38, 3.22s/it, lpips=0.757]
LPIPS : 0.7572613871297357 || SSIM : 0.03543620411951782 || FID : 8.010747142344213
  2%|█▊                                                                                             | 179/9.11k [05:39<4:41:54, 1.89s/it, lpips=0.757]
Traceback (most recent call last):
  File "/content/lama/eval.py", line 82, in <module>
    fid_metric += fid.compute().item()
  File "/usr/local/lib/python3.10/dist-packages/torchmetrics/metric.py", line 632, in wrapped_func
    value = _squeeze_if_scalar(compute(*args, **kwargs))
  File "/usr/local/lib/python3.10/dist-packages/torchmetrics/image/fid.py", line 391, in compute
    return _compute_fid(mean_real.squeeze(0), cov_real, mean_fake.squeeze(0), cov_fake).to(self.orig_dtype)
  File "/usr/local/lib/python3.10/dist-packages/torchmetrics/image/fid.py", line 177, in _compute_fid
    c = torch.linalg.eigvals(sigma1 @ sigma2).sqrt().real.sum(dim=-1)
KeyboardInterrupt
^C
"""
