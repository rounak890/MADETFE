# %%
import torchvision

# transf = torchvision.transforms.Compose([
#     torchvision.transforms.Grayscale(num_output_channels=3)
# ])

train = torchvision.datasets.Places365(root = "data/", split = 'val', small = True, download = True)
train
# Out:
# ...
# 100%|██████████| 67498496/67498496 [00:01<00:00, 56658908.61it/s]
# Extracting data/filelist_places365-standard.tar to data/
# ...
# 100%|██████████| 525158400/525158400 [00:09<00:00, 54379228.18it/s]
# Extracting data/val_256.tar to data/
# Dataset Places365
#     Number of datapoints: 36500
#     Root location: data/
#     Split: val
#     Small: True

# %%
# !git clone https://github.com/gabrielBarbutti/lama.git
# Out:
# Cloning into 'lama'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 69 (delta 36), reused 39 (delta 19), pack-reused 0
# Receiving objects: 100% (69/69), 27.17 KiB | 1.60 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# !ls
# Out:
# data  lama  sample_data

# %%
import os
from pathlib import Path
import shutil
path = Path("data/val_256/")
# os.listdir(path)

# %%
from PIL import Image
import numpy

x = Image.open("data/val_256/Places365_val_00000010.jpg")   #all have (256,256) size
numpy.array(x).shape
# Out:
# (256, 256, 3)

# %%
from PIL import Image
import numpy

count = 0
for i in os.listdir(path):
  img = Image.open(path/i)
  if numpy.array(img).shape[-1] != 3:
    os.remove(path/i)
    count += 1

print(f"count : {count}")
# Out:
# count : 79

# %%
# for training
# !python lama/main.py --experiment baseline --data_path data/val_256 #Path/of/your/dataset   [baseline, conv_change or wgan]
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:08<00:00, 65.4MB/s]
# Downloading: "http://sceneparsing.csail.mit.edu/model/pretrained_resnet/resnet50-imagenet.pth" to ./pretrained/resnet50-imagenet.pth
# ################ TRAINING STARTED ################
# Epoch 1 of 50
# ...

# %%
# # for testing with pretrained weights / trained
# !python lama/eval.py --experiment baseline \
#                 --data_path /data/val_256 #Path/of/your/testset \
#                 --checkpoint_path model_weights #Path/of/your/weight

# %%
# !pip install -q lpips
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 817.8 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 51.1 MB/s eta 0:00:00

# %%
# !gdown 1viaxl1sYNSp6wQLDRk2Z1NqFYdKgQWqz
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1viaxl1sYNSp6wQLDRk2Z1NqFYdKgQWqz
# From (redirected): https://drive.google.com/uc?id=1viaxl1sYNSp6wQLDRk2Z1NqFYdKgQWqz&confirm=t&uuid=48c7213a-f58f-4421-92b5-a997bfa5e19b
# To: /content/model_epochs_17_batch_3000_03-01-2022_08h22.pth
# 100% 74.0M/74.0M [00:01<00:00, 57.0MB/s]

# %%
# !python lama/eval.py --experiment baseline --data_path data/val_256  --checkpoint_path 2.pth

# at line 66 and aso create 2 folders named only_masked and masked
# save_image(stack[j][3,:,:], 'only_masked/'+dataset.paths[(4*i)+j])
# save_image(stack[j][:3,:,:], 'masked/'+dataset.paths[(4*i)+j])
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
# ...

# %%
# !python lama/eval.py --experiment baseline --data_path data/val_256  --checkpoint_path 2.pth
# in eval.py comment out line 3 and last line
# also rename the weights file to 1 for ease
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copytree("/content/test_images", "/content/drive/MyDrive/LAMA_MAT/lama_test_images22")
# Out:
# '/content/drive/MyDrive/LAMA_MAT/lama_test_images22'

# %%
import shutil
shutil.copytree("/content/only_masked", "/content/drive/MyDrive/LAMA_MAT/lama_only_masked")
# Out:
# '/content/drive/MyDrive/LAMA_MAT/lama_only_masked'

# %%
import shutil
shutil.copytree("/content/masked", "/content/drive/MyDrive/LAMA_MAT/lama_masked")
# Out:
# '/content/drive/MyDrive/LAMA_MAT/lama_masked'

# %%
import shutil
shutil.copy("/content/masked.zip", "/content/drive/MyDrive/lama_masked.zip")
# Out:
# '/content/drive/MyDrive/lama_masked.zip'

# %%
# !zip -r /content/only_maksed.zip /content/only_masked
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/only_masked/Places365_val_00027317.jpg (deflated 27%)
#   adding: content/only_masked/Places365_val_00017574.jpg (deflated 58%)
#   adding: content/only_masked/Places365_val_00021497.jpg (deflated 40%)
#   adding: content/only_masked/Places365_val_00002379.jpg (deflated 55%)
#   adding: content/only_masked/Places365_val_00013868.jpg (deflated 40%)
#   adding: content/only_masked/Places365_val_00002531.jpg (deflated 30%)
#   adding: content/only_masked/Places365_val_00014745.jpg (deflated 50%)
#   adding: content/only_masked/Places365_val_00000040.jpg (deflated 35%)
#   adding: content/only_masked/Places365_val_00001052.jpg (deflated 35%)
#   adding: content/only_masked/Places365_val_00013445.jpg (deflated 56%)
#   adding: content/only_masked/Places365_val_00031171.jpg (deflated 69%)
#   adding: content/only_masked/Places365_val_00022058.jpg (deflated 34%)
# ...

# %%
# !zip -r /content/masked.zip /content/masked
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/masked/Places365_val_00027317.jpg (deflated 2%)
#   adding: content/masked/Places365_val_00017574.jpg (deflated 2%)
#   adding: content/masked/Places365_val_00021497.jpg (deflated 1%)
#   adding: content/masked/Places365_val_00002379.jpg (deflated 1%)
#   adding: content/masked/Places365_val_00013868.jpg (deflated 1%)
#   adding: content/masked/Places365_val_00002531.jpg (deflated 2%)
#   adding: content/masked/Places365_val_00014745.jpg (deflated 2%)
#   adding: content/masked/Places365_val_00000040.jpg (deflated 2%)
#   adding: content/masked/Places365_val_00001052.jpg (deflated 2%)
#   adding: content/masked/Places365_val_00013445.jpg (deflated 3%)
#   adding: content/masked/Places365_val_00031171.jpg (deflated 3%)
#   adding: content/masked/Places365_val_00022058.jpg (deflated 1%)
#   adding: content/masked/Places365_val_00021757.jpg (deflated 2%)
# ...

# %%
    # if image.shape[-1] != 3:
    #   return image

# %%
# import os
# from pathlib import Path
# import shutil

# new = "all_data/"
# path = Path("data/val_256/")

# path.mkdir(parents = True, exist_ok = True)

#For TEST-> ALREADY DONE NO NEED
# FOR TRAIN DATA
# for i in os.listdir(path):
#   for j in os.listdir(path/i):
#     gener = Path(path / i / j).glob('*.jpg')
#     for k in gener:
#       shutil.copy(k,new)
