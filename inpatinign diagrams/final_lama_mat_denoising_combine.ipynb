# %%
# !pip install -q gdown torchmetrics lpips torch-fidelity
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.2 MB/s eta 0:00:00

# %%
# !gdown 14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl
# From (redirected): https://drive.google.com/uc?id=14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl&confirm=t&uuid=5ed7de5d-9cfa-41a4-820e-03ba604c2609
# To: /content/final_train_images_for_lama_mat.zip
# 100% 21.7M/21.7M [00:00<00:00, 45.0MB/s]

# %%
# !gdown 1Ce1pB1n3Vldc6kKFihBU7ZFmnSi9RyEK
# !gdown 1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE
# !gdown 1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ce1pB1n3Vldc6kKFihBU7ZFmnSi9RyEK
# To: /content/masks.zip
# 100% 2.66M/2.66M [00:00<00:00, 157MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE
# From (redirected): https://drive.google.com/uc?id=1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE&confirm=t&uuid=44c9ad94-bec9-4563-b55e-5a7e031ff663
# To: /content/lama_imgs.zip
# 100% 23.9M/23.9M [00:00<00:00, 44.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj
# From (redirected): https://drive.google.com/uc?id=1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj&confirm=t&uuid=9687a212-87e8-45e0-9928-88bcd8bd4797
# To: /content/mat_images.zip
# 100% 122M/122M [00:02<00:00, 52.9MB/s]

# %%
# getting neccesary files downloaded
import gdown
urls= [
    'https://drive.google.com/file/d/14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl', # all imgs
    "https://drive.google.com/file/d/1Ce1pB1n3Vldc6kKFihBU7ZFmnSi9RyEK", # only_masked
    "https://drive.google.com/file/d/1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE", # lama
    "https://drive.google.com/file/d/1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj" # mat
      ]

for url in urls:
    gdown.download(url)
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl
# To: /content/14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl
# 89.5kB [00:00, 4.52MB/s]
# Downloading...
# From: https://drive.google.com/file/d/1Ce1pB1n3Vldc6kKFihBU7ZFmnSi9RyEK
# To: /content/1Ce1pB1n3Vldc6kKFihBU7ZFmnSi9RyEK
# 89.6kB [00:00, 2.41MB/s]
# Downloading...
# From: https://drive.google.com/file/d/1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE
# To: /content/1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE
# 89.5kB [00:00, 2.36MB/s]
# Downloading...
# From: https://drive.google.com/file/d/1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj
# To: /content/1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj
# 89.5kB [00:00, 3.09MB/s]

# %%
# !ls
# Out:
# 14so9XcDaE_BL2VoJ2qdKjmLm6t0QrzFl  1_HSL5d9EnJAamdpg7Hu_sRBPGOkVjRuE  neww
# 1Ce1pB1n3Vldc6kKFihBU7ZFmnSi9RyEK  1JpJg_F86TGwwco5G1UVb3JOYGtNT9gvj  sample_data

# %%
#making the unzip function
import zipfile
import os

def unzip_file(zip_path, extract_to):
    if not os.path.exists(extract_to):
        os.makedirs(extract_to)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print(f'Extracted all files to {extract_to}')

# %%
#usng the unzip function
unzip_file("masks.zip", "neww")
unzip_file("final_train_images_for_lama_mat.zip", "neww")
unzip_file("lama_imgs.zip", "neww")
unzip_file("mat_images.zip", "neww")
# Out:
# Extracted all files to neww
# Extracted all files to neww
# Extracted all files to neww
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-57ba5d5c4ca9> in <cell line: 5>()
#       3 unzip_file("final_train_images_for_lama_mat.zip", "neww")
#       4 unzip_file("lama_imgs.zip", "neww")
# ----> 5 unzip_file("mat_imgs.zip", "neww")
#
# <ipython-input-3-a36fead0b75a> in unzip_file(zip_path, extract_to)
#       7         os.makedirs(extract_to)
#       8
# ----> 9     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#      10         zip_ref.extractall(extract_to)
#      11     print(f'Extracted all files to {extract_to}')
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1252             while True:
#    1253                 try:
# -> 1254                     self.fp = io.open(file, filemode)
#    1255                 except OSError:
#    1256                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mat_imgs.zip'

# %%
unzip_file("mat_images.zip", "neww")
# Out:
# Extracted all files to neww

# %%
# # downloading the dataset
# import torchvision

# train = torchvision.datasets.Places365(root = "data/", split = 'val', small = True, download = True )
# train
# Out:
# Downloading https://data.csail.mit.edu/places/places365/filelist_places365-standard.tar to data/filelist_places365-standard.tar
# 100%|██████████| 67498496/67498496 [00:02<00:00, 30506110.37it/s]
# Extracting data/filelist_places365-standard.tar to data/
# Downloading https://data.csail.mit.edu/places/places365/val_256.tar to data/val_256.tar
# 100%|██████████| 525158400/525158400 [00:12<00:00, 42893209.66it/s]
# Extracting data/val_256.tar to data/
# Dataset Places365
#     Number of datapoints: 36500
#     Root location: data/
#     Split: val
#     Small: True

# %%
# reoving the wrong files
from pathlib import Path
import os
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
from PIL import Image

path = Path("data/val_256/")

# if we will use train data then it would have folders many of diff objects while in validation set there is no such complicaion
# removing the improper images
count = 0
for i in os.listdir(path):
  img = plt.imread(path/i)
  if img.shape[-1] != 3:
    os.remove(path/i)
    count += 1

print(f"Deleted images with incorrect number of dims : {count}")
# Out:
# Deleted images with incorrect number of dims : 79

# %%
# checking the number of each imgs
from pathlib import Path
import pandas as pd

path0 = Path("data/val_256/")
path = Path("neww/content/drive/MyDrive/LAMA_MAT/mat_test_images")
path2 = Path("neww/content/drive/MyDrive/LAMA_MAT/lama_test_images22")
path3 = Path("neww/content/only_masked")

l0 = list(path0.glob("*.jpg"))
l1 = list(path.glob("*.png"))
l2 = list(path2.glob("*.jpg"))
l3 = list(path3.glob("*.jpg"))

l0.sort()
l1.sort()
l2.sort()
l3.sort()
print(len(l0),len(l1), len(l2), len(l3))
# Out:
# 36421 7527 22479 36421

# %%
from pathlib  import Path

path = Path('/content/neww/train_images')
imgs =  list(path.glob("*.jpg"))

for i in imgs:
  print(i.as_posix())
  print(i.as_posix().split("/"))
  print(i.as_posix().split("/")[-1])
  print(i.as_posix().split("/")[-1].split("."))
  print(i.as_posix().split("/")[-1].split(".")[0])
  break
# Out:
# /content/neww/train_images/yard1397.jpg
# ['', 'content', 'neww', 'train_images', 'yard1397.jpg']
# yard1397.jpg
# ['yard1397', 'jpg']
# yard1397

# %%
os.path.exists('/content/neww/out_path_rg/airfield1446_.png')
# Out:
# True

# %%
# !gdown 1GVgwCWCvwTD8rwRUbL_NdNO9w5FsNEDt # new train imgs
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GVgwCWCvwTD8rwRUbL_NdNO9w5FsNEDt
# To: /content/train_images_for_lama_mat.zip
# 100% 21.8M/21.8M [00:01<00:00, 17.0MB/s]

# %%
unzip_file("train_images_for_lama_mat.zip", "neww")
# Out:
# Extracted all files to neww

# %%
from pathlib import Path
import shutil

save_path = Path('meow')
path = Path('neww/train_images_for_lama_mat/')
z = 0

for i in os.listdir(path):
  for j in os.listdir(path/i):
    shutil.copy(path/i/j, save_path/(str(i)+str(z)+"_"+'.jpg'))
    z += 1

print(z)
# Out:
# 1571

# %%
# !zip -r finnnally_made_train_imgs.zip meow
# Out:
#   adding: meow/ (stored 0%)
#   adding: meow/coffee_shop74_.jpg (deflated 1%)
#   adding: meow/asia492_.jpg (deflated 1%)
#   adding: meow/science_museum1472_.jpg (deflated 2%)
#   adding: meow/ski_slope223_.jpg (deflated 1%)
#   adding: meow/ski_resort1311_.jpg (deflated 1%)
#   adding: meow/landing_deck1209_.jpg (deflated 1%)
#   adding: meow/computer_room411_.jpg (deflated 1%)
#   adding: meow/bar434_.jpg (deflated 1%)
#   adding: meow/ruin500_.jpg (deflated 1%)
#   adding: meow/cafeteria1437_.jpg (deflated 1%)
#   adding: meow/engine_room783_.jpg (deflated 1%)
#   adding: meow/car_interior368_.jpg (deflated 1%)
#   adding: meow/football614_.jpg (deflated 2%)
#   adding: meow/beer_garden1047_.jpg (deflated 1%)
#   adding: meow/butchers_shop859_.jpg (deflated 1%)
#   adding: meow/toyshop62_.jpg (deflated 1%)
#   adding: meow/sandbox114_.jpg (deflated 2%)
#   adding: meow/hospital_room154_.jpg (deflated 1%)
#   adding: meow/windmill928_.jpg (deflated 3%)
#   adding: meow/butte15_.jpg (deflated 2%)
#   adding: meow/catacomb843_.jpg (deflated 1%)
#   adding: meow/rainforest1491_.jpg (deflated 1%)
#   adding: meow/village735_.jpg (deflated 1%)
#   adding: meow/formal_garden655_.jpg (deflated 1%)
#   adding: meow/cliff131_.jpg (deflated 1%)
#   adding: meow/village736_.jpg (deflated 1%)
#   adding: meow/corridor935_.jpg (deflated 1%)
#   adding: meow/martial_arts_gym763_.jpg (deflated 1%)
#   adding: meow/village739_.jpg (deflated 6%)
#   adding: meow/cliff133_.jpg (deflated 1%)
#   adding: meow/yard506_.jpg (deflated 1%)
#   adding: meow/hardware_store1213_.jpg (deflated 1%)
#   adding: meow/grotto570_.jpg (deflated 1%)
#   adding: meow/iceberg1505_.jpg (deflated 2%)
#   adding: meow/utility_room1171_.jpg (deflated 1%)
#   adding: meow/industrial_area91_.jpg (deflated 1%)
#   adding: meow/dam173_.jpg (deflated 1%)
#   adding: meow/office_building727_.jpg (deflated 2%)
#   adding: meow/yard505_.jpg (deflated 2%)
#   adding: meow/bamboo_forest378_.jpg (deflated 1%)
#   adding: meow/restaurant1384_.jpg (deflated 1%)
#   adding: meow/asia491_.jpg (deflated 1%)
#   adding: meow/hospital881_.jpg (deflated 2%)
#   adding: meow/roof_garden158_.jpg (deflated 1%)
#   adding: meow/medina1466_.jpg (deflated 1%)
#   adding: meow/raceway305_.jpg (deflated 1%)
#   adding: meow/physics_laboratory1025_.jpg (deflated 1%)
#   adding: meow/palace162_.jpg (deflated 1%)
#   adding: meow/jail_cell822_.jpg (deflated 1%)
#   adding: meow/bullring123_.jpg (deflated 1%)
#   adding: meow/beach_house714_.jpg (deflated 1%)
#   adding: meow/dining_hall462_.jpg (deflated 1%)
#   adding: meow/repair_shop24_.jpg (deflated 1%)
#   adding: meow/cottage276_.jpg (deflated 1%)
#   adding: meow/desert_road1509_.jpg (deflated 1%)
#   adding: meow/heliport1293_.jpg (deflated 2%)
#   adding: meow/entrance_hall1137_.jpg (deflated 1%)
#   adding: meow/alcove436_.jpg (deflated 1%)
#   adding: meow/natural333_.jpg (deflated 2%)
#   adding: meow/veterinarians_office1355_.jpg (deflated 2%)
#   adding: meow/amphitheater875_.jpg (deflated 1%)
#   adding: meow/jewelry_shop1254_.jpg (deflated 1%)
#   adding: meow/amusement_park11_.jpg (deflated 1%)
#   adding: meow/legislative_chamber361_.jpg (deflated 2%)
#   adding: meow/waterfall1565_.jpg (deflated 1%)
#   adding: meow/cemetery1187_.jpg (deflated 1%)
#   adding: meow/bookstore311_.jpg (deflated 1%)
#   adding: meow/boathouse1517_.jpg (deflated 1%)
#   adding: meow/ocean_deep105_.jpg (deflated 1%)
#   adding: meow/office_cubicles207_.jpg (deflated 1%)
#   adding: meow/forest_path1432_.jpg (deflated 1%)
#   adding: meow/botanical_garden196_.jpg (deflated 1%)
#   adding: meow/formal_garden658_.jpg (deflated 1%)
#   adding: meow/fire_station1415_.jpg (deflated 1%)
#   adding: meow/campus1158_.jpg (deflated 1%)
#   adding: meow/legislative_chamber362_.jpg (deflated 1%)
#   adding: meow/wet_bar303_.jpg (deflated 1%)
#   adding: meow/lecture_room265_.jpg (deflated 1%)
#   adding: meow/public941_.jpg (deflated 1%)
#   adding: meow/igloo1477_.jpg (deflated 2%)
#   adding: meow/burial_chamber117_.jpg (deflated 1%)
#   adding: meow/motel42_.jpg (deflated 1%)
#   adding: meow/mausoleum481_.jpg (deflated 1%)
#   adding: meow/mountain_path755_.jpg (deflated 1%)
#   adding: meow/mountain1527_.jpg (deflated 1%)
#   adding: meow/recreation_room288_.jpg (deflated 1%)
#   adding: meow/public943_.jpg (deflated 1%)
#   adding: meow/classroom1305_.jpg (deflated 1%)
#   adding: meow/ball_pit1163_.jpg (deflated 1%)
#   adding: meow/classroom1301_.jpg (deflated 1%)
#   adding: meow/bookstore313_.jpg (deflated 1%)
#   adding: meow/martial_arts_gym761_.jpg (deflated 1%)
#   adding: meow/storage_room104_.jpg (deflated 1%)
#   adding: meow/barndoor1141_.jpg (deflated 1%)
#   adding: meow/mountain_snowy665_.jpg (deflated 1%)
#   adding: meow/junkyard811_.jpg (deflated 1%)
#   adding: meow/ice_floe36_.jpg (deflated 2%)
#   adding: meow/shower204_.jpg (deflated 2%)
#   adding: meow/carrousel384_.jpg (deflated 1%)
#   adding: meow/physics_laboratory1026_.jpg (deflated 1%)
#   adding: meow/drugstore428_.jpg (deflated 1%)
#   adding: meow/sauna768_.jpg (deflated 2%)
#   adding: meow/reception1250_.jpg (deflated 1%)
#   adding: meow/picnic_area715_.jpg (deflated 1%)
#   adding: meow/ski_resort1313_.jpg (deflated 1%)
#   adding: meow/pavilion1216_.jpg (deflated 1%)
#   adding: meow/platform625_.jpg (deflated 3%)
#   adding: meow/phone_booth566_.jpg (deflated 2%)
#   adding: meow/courthouse954_.jpg (deflated 1%)
#   adding: meow/soccer607_.jpg (deflated 1%)
#   adding: meow/porch960_.jpg (deflated 1%)
#   adding: meow/mansion281_.jpg (deflated 2%)
#   adding: meow/sand401_.jpg (deflated 1%)
#   adding: meow/motel41_.jpg (deflated 1%)
#   adding: meow/pond511_.jpg (deflated 1%)
#   adding: meow/assembly_line529_.jpg (deflated 1%)
#   adding: meow/fastfood_restaurant1276_.jpg (deflated 1%)
#   adding: meow/fire_station1411_.jpg (deflated 1%)
#   adding: meow/landfill466_.jpg (deflated 1%)
#   adding: meow/corral959_.jpg (deflated 1%)
#   adding: meow/medina1467_.jpg (deflated 1%)
#   adding: meow/driveway446_.jpg (deflated 1%)
#   adding: meow/shed598_.jpg (deflated 1%)
#   adding: meow/operating_room635_.jpg (deflated 2%)
#   adding: meow/bullring124_.jpg (deflated 1%)
#   adding: meow/cultivated802_.jpg (deflated 1%)
#   adding: meow/alcove437_.jpg (deflated 1%)
#   adding: meow/nursing_home1444_.jpg (deflated 2%)
#   adding: meow/kasbah348_.jpg (deflated 1%)
#   adding: meow/baseball751_.jpg (deflated 1%)
#   adding: meow/swimming_hole1459_.jpg (deflated 1%)
#   adding: meow/rice_paddy1226_.jpg (deflated 2%)
#   adding: meow/butte19_.jpg (deflated 2%)
#   adding: meow/zen_garden1086_.jpg (deflated 1%)
#   adding: meow/lighthouse422_.jpg (deflated 3%)
#   adding: meow/indoor1244_.jpg (deflated 1%)
#   adding: meow/army_base544_.jpg (deflated 1%)
#   adding: meow/veterinarians_office1352_.jpg (deflated 1%)
#   adding: meow/restaurant_kitchen1402_.jpg (deflated 1%)
#   adding: meow/conference_room1566_.jpg (deflated 2%)
#   adding: meow/asia493_.jpg (deflated 2%)
#   adding: meow/schoolhouse1073_.jpg (deflated 1%)
#   adding: meow/kindergarden_classroom849_.jpg (deflated 1%)
#   adding: meow/television_room537_.jpg (deflated 2%)
#   adding: meow/lock_chamber1112_.jpg (deflated 1%)
#   adding: meow/sand402_.jpg (deflated 3%)
#   adding: meow/vegetation228_.jpg (deflated 1%)
#   adding: meow/coffee_shop72_.jpg (deflated 1%)
#   adding: meow/rainforest1494_.jpg (deflated 1%)
#   adding: meow/heliport1295_.jpg (deflated 1%)
#   adding: meow/fire_escape911_.jpg (deflated 1%)
#   adding: meow/pavilion1217_.jpg (deflated 1%)
#   adding: meow/fountain51_.jpg (deflated 1%)
#   adding: meow/park1380_.jpg (deflated 1%)
#   adding: meow/shoe_shop1178_.jpg (deflated 2%)
#   adding: meow/hardware_store1212_.jpg (deflated 1%)
#   adding: meow/landing_deck1206_.jpg (deflated 1%)
#   adding: meow/raceway309_.jpg (deflated 1%)
#   adding: meow/patio1533_.jpg (deflated 1%)
#   adding: meow/fabric_store1121_.jpg (deflated 1%)
#   adding: meow/cottage279_.jpg (deflated 1%)
#   adding: meow/skyscraper887_.jpg (deflated 2%)
#   adding: meow/embassy315_.jpg (deflated 1%)
#   adding: meow/basement653_.jpg (deflated 3%)
#   adding: meow/schoolhouse1074_.jpg (deflated 3%)
#   adding: meow/ski_slope224_.jpg (deflated 1%)
#   adding: meow/childs_room663_.jpg (deflated 1%)
#   adding: meow/islet560_.jpg (deflated 2%)
#   adding: meow/clothing_store1239_.jpg (deflated 1%)
#   adding: meow/rock_arch398_.jpg (deflated 2%)
#   adding: meow/amphitheater879_.jpg (deflated 1%)
#   adding: meow/home_office976_.jpg (deflated 1%)
#   adding: meow/art_gallery834_.jpg (deflated 1%)
#   adding: meow/bedchamber1005_.jpg (deflated 1%)
#   adding: meow/residential_neighborhood7_.jpg (deflated 1%)
#   adding: meow/hockey441_.jpg (deflated 1%)
#   adding: meow/broadleaf591_.jpg (deflated 1%)
#   adding: meow/food_court788_.jpg (deflated 1%)
#   adding: meow/supermarket699_.jpg (deflated 1%)
#   adding: meow/bamboo_forest379_.jpg (deflated 1%)
#   adding: meow/pavilion1219_.jpg (deflated 1%)
#   adding: meow/porch961_.jpg (deflated 1%)
#   adding: meow/golf_course1365_.jpg (deflated 1%)
#   adding: meow/basement654_.jpg (deflated 2%)
#   adding: meow/barn894_.jpg (deflated 1%)
#   adding: meow/bathroom1017_.jpg (deflated 2%)
#   adding: meow/staircase48_.jpg (deflated 1%)
#   adding: meow/golf_course1361_.jpg (deflated 3%)
#   adding: meow/ball_pit1162_.jpg (deflated 1%)
#   adding: meow/exterior353_.jpg (deflated 2%)
#   adding: meow/music_studio863_.jpg (deflated 1%)
#   adding: meow/shopfront419_.jpg (deflated 1%)
#   adding: meow/orchestra_pit722_.jpg (deflated 1%)
#   adding: meow/elevator_shaft1013_.jpg (deflated 1%)
#   adding: meow/classroom1302_.jpg (deflated 1%)
#   adding: meow/natural_history_museum1146_.jpg (deflated 1%)
#   adding: meow/tree_farm1038_.jpg (deflated 1%)
#   adding: meow/courtyard30_.jpg (deflated 1%)
#   adding: meow/bus_interior1319_.jpg (deflated 1%)
#   adding: meow/baseball_field631_.jpg (deflated 1%)
#   adding: meow/house1261_.jpg (deflated 1%)
#   adding: meow/amusement_arcade989_.jpg (deflated 1%)
#   adding: meow/field_road817_.jpg (deflated 2%)
#   adding: meow/television_room535_.jpg (deflated 1%)
#   adding: meow/server_room709_.jpg (deflated 1%)
#   adding: meow/shopfront415_.jpg (deflated 1%)
#   adding: meow/lecture_room269_.jpg (deflated 1%)
#   adding: meow/lawn235_.jpg (deflated 1%)
#   adding: meow/ruin503_.jpg (deflated 1%)
#   adding: meow/botanical_garden197_.jpg (deflated 1%)
#   adding: meow/shower202_.jpg (deflated 1%)
#   adding: meow/boat_deck685_.jpg (deflated 1%)
#   adding: meow/fastfood_restaurant1278_.jpg (deflated 1%)
#   adding: meow/elevator_shaft1011_.jpg (deflated 1%)
#   adding: meow/nursing_home1445_.jpg (deflated 1%)
#   adding: meow/bedchamber1007_.jpg (deflated 1%)
#   adding: meow/conference_center1021_.jpg (deflated 2%)
#   adding: meow/restaurant_kitchen1405_.jpg (deflated 1%)
#   adding: meow/shed599_.jpg (deflated 2%)
#   adding: meow/raft999_.jpg (deflated 1%)
#   adding: meow/hayfield807_.jpg (deflated 2%)
#   adding: meow/hot_spring485_.jpg (deflated 4%)
#   adding: meow/clothing_store1238_.jpg (deflated 1%)
#   adding: meow/dorm_room701_.jpg (deflated 1%)
#   adding: meow/porch963_.jpg (deflated 1%)
#   adding: meow/office_building729_.jpg (deflated 1%)
#   adding: meow/lagoon905_.jpg (deflated 2%)
#   adding: meow/indoor1243_.jpg (deflated 1%)
#   adding: meow/laundromat1488_.jpg (deflated 1%)
#   adding: meow/sushi_bar1398_.jpg (deflated 1%)
#   adding: meow/television_room536_.jpg (deflated 1%)
#   adding: meow/badlands1537_.jpg (deflated 2%)
#   adding: meow/zen_garden1087_.jpg (deflated 1%)
#   adding: meow/butchers_shop858_.jpg (deflated 1%)
#   adding: meow/bookstore310_.jpg (deflated 1%)
#   adding: meow/tundra1266_.jpg (deflated 1%)
#   adding: meow/building_facade1231_.jpg (deflated 1%)
#   adding: meow/hockey444_.jpg (deflated 1%)
#   adding: meow/shower201_.jpg (deflated 1%)
#   adding: meow/auto_factory356_.jpg (deflated 1%)
#   adding: meow/auto_showroom1337_.jpg (deflated 2%)
#   adding: meow/valley552_.jpg (deflated 1%)
#   adding: meow/rainforest1493_.jpg (deflated 1%)
#   adding: meow/street127_.jpg (deflated 1%)
#   adding: meow/boat_deck687_.jpg (deflated 1%)
#   adding: meow/bedroom1053_.jpg (deflated 1%)
#   adding: meow/sand400_.jpg (deflated 2%)
#   adding: meow/bowling_alley0_.jpg (deflated 1%)
#   adding: meow/castle618_.jpg (deflated 2%)
#   adding: meow/shop407_.jpg (deflated 1%)
#   adding: meow/oilrig684_.jpg (deflated 1%)
#   adding: meow/broadleaf594_.jpg (deflated 1%)
#   adding: meow/dam174_.jpg (deflated 1%)
#   adding: meow/swimming_hole1456_.jpg (deflated 1%)
#   adding: meow/pond512_.jpg (deflated 1%)
#   adding: meow/field_road819_.jpg (deflated 2%)
#   adding: meow/music_studio860_.jpg (deflated 1%)
#   adding: meow/cockpit1184_.jpg (deflated 1%)
#   adding: meow/bathroom1018_.jpg (deflated 2%)
#   adding: meow/vegetable_garden1098_.jpg (deflated 1%)
#   adding: meow/crevasse458_.jpg (deflated 2%)
#   adding: meow/desert_road1510_.jpg (deflated 4%)
#   adding: meow/boat_deck686_.jpg (deflated 1%)
#   adding: meow/door1331_.jpg (deflated 6%)
#   adding: meow/crosswalk1134_.jpg (deflated 1%)
#   adding: meow/baseball753_.jpg (deflated 1%)
#   adding: meow/water_park169_.jpg (deflated 2%)
#   adding: meow/dam172_.jpg (deflated 1%)
#   adding: meow/hayfield805_.jpg (deflated 1%)
#   adding: meow/carrousel383_.jpg (deflated 1%)
#   adding: meow/legislative_chamber360_.jpg (deflated 1%)
#   adding: meow/entrance_hall1135_.jpg (deflated 2%)
#   adding: meow/barndoor1140_.jpg (deflated 1%)
#   adding: meow/ice_floe39_.jpg (deflated 1%)
#   adding: meow/train_interior920_.jpg (deflated 1%)
#   adding: meow/berth1128_.jpg (deflated 1%)
#   adding: meow/igloo1476_.jpg (deflated 1%)
#   adding: meow/wheat_field1102_.jpg (deflated 1%)
#   adding: meow/butte18_.jpg (deflated 1%)
#   adding: meow/television_room538_.jpg (deflated 1%)
#   adding: meow/excavation917_.jpg (deflated 1%)
#   adding: meow/canyon623_.jpg (deflated 1%)
#   adding: meow/house1264_.jpg (deflated 1%)
#   adding: meow/landfill465_.jpg (deflated 1%)
#   adding: meow/windmill929_.jpg (deflated 2%)
#   adding: meow/door1332_.jpg (deflated 1%)
#   adding: meow/ticket_booth142_.jpg (deflated 1%)
#   adding: meow/parking_lot385_.jpg (deflated 1%)
#   adding: meow/computer_room413_.jpg (deflated 1%)
#   adding: meow/mountain_snowy668_.jpg (deflated 3%)
#   adding: meow/shed595_.jpg (deflated 1%)
#   adding: meow/volcano901_.jpg (deflated 2%)
#   adding: meow/waterfall1564_.jpg (deflated 1%)
#   adding: meow/ice_floe38_.jpg (deflated 2%)
#   adding: meow/restaurant1381_.jpg (deflated 1%)
#   adding: meow/bridge524_.jpg (deflated 1%)
#   adding: meow/corn_field1525_.jpg (deflated 1%)
#   adding: meow/exterior351_.jpg (deflated 1%)
#   adding: meow/wheat_field1104_.jpg (deflated 2%)
#   adding: meow/wild263_.jpg (deflated 1%)
#   adding: meow/pond510_.jpg (deflated 1%)
#   adding: meow/playroom28_.jpg (deflated 1%)
#   adding: meow/bamboo_forest376_.jpg (deflated 1%)
#   adding: meow/crevasse455_.jpg (deflated 1%)
#   adding: meow/arcade799_.jpg (deflated 1%)
#   adding: meow/pharmacy1416_.jpg (deflated 1%)
#   adding: meow/airfield1446_.jpg (deflated 1%)
#   adding: meow/valley553_.jpg (deflated 1%)
#   adding: meow/phone_booth565_.jpg (deflated 1%)
#   adding: meow/bedchamber1008_.jpg (deflated 2%)
#   adding: meow/playground1150_.jpg (deflated 1%)
#   adding: meow/tree_farm1036_.jpg (deflated 1%)
#   adding: meow/engine_room784_.jpg (deflated 1%)
#   adding: meow/beer_hall548_.jpg (deflated 1%)
#   adding: meow/burial_chamber118_.jpg (deflated 1%)
#   adding: meow/storage_room100_.jpg (deflated 1%)
#   adding: meow/mansion280_.jpg (deflated 1%)
#   adding: meow/raft996_.jpg (deflated 1%)
#   adding: meow/alcove435_.jpg (deflated 1%)
#   adding: meow/dressing_room84_.jpg (deflated 1%)
#   adding: meow/food_court789_.jpg (deflated 1%)
#   adding: meow/jail_cell823_.jpg (deflated 1%)
#   adding: meow/loading_dock1204_.jpg (deflated 1%)
#   adding: meow/aqueduct77_.jpg (deflated 1%)
#   adding: meow/performance1555_.jpg (deflated 3%)
#   adding: meow/soccer608_.jpg (deflated 1%)
#   adding: meow/waiting_room370_.jpg (deflated 1%)
#   adding: meow/campsite874_.jpg (deflated 1%)
#   adding: meow/volcano904_.jpg (deflated 2%)
#   adding: meow/ruin504_.jpg (deflated 1%)
#   adding: meow/lock_chamber1110_.jpg (deflated 1%)
#   adding: meow/boardwalk970_.jpg (deflated 2%)
#   adding: meow/office_building725_.jpg (deflated 1%)
#   adding: meow/pizzeria232_.jpg (deflated 1%)
#   adding: meow/soccer605_.jpg (deflated 2%)
#   adding: meow/coffee_shop73_.jpg (deflated 1%)
#   adding: meow/football_field1068_.jpg (deflated 1%)
#   adding: meow/airplane_cabin867_.jpg (deflated 1%)
#   adding: meow/interior740_.jpg (deflated 1%)
#   adding: meow/pagoda980_.jpg (deflated 1%)
#   adding: meow/jail_cell820_.jpg (deflated 1%)
#   adding: meow/swamp296_.jpg (deflated 1%)
#   adding: meow/sandbox112_.jpg (deflated 1%)
#   adding: meow/candy_store585_.jpg (deflated 1%)
#   adding: meow/repair_shop22_.jpg (deflated 1%)
#   adding: meow/downtown393_.jpg (deflated 1%)
#   adding: meow/construction_site968_.jpg (deflated 1%)
#   adding: meow/pasture1078_.jpg (deflated 1%)
#   adding: meow/ticket_booth144_.jpg (deflated 1%)
#   adding: meow/beer_garden1045_.jpg (deflated 1%)
#   adding: meow/exterior350_.jpg (deflated 1%)
#   adding: meow/office_cubicles209_.jpg (deflated 1%)
#   adding: meow/grotto572_.jpg (deflated 1%)
#   adding: meow/bowling_alley4_.jpg (deflated 2%)
#   adding: meow/highway1368_.jpg (deflated 1%)
#   adding: meow/park1379_.jpg (deflated 1%)
#   adding: meow/sauna769_.jpg (deflated 1%)
#   adding: meow/cultivated801_.jpg (deflated 1%)
#   adding: meow/orchestra_pit723_.jpg (deflated 1%)
#   adding: meow/home_theater1327_.jpg (deflated 3%)
#   adding: meow/industrial_area94_.jpg (deflated 1%)
#   adding: meow/shopfront417_.jpg (deflated 1%)
#   adding: meow/beer_hall549_.jpg (deflated 1%)
#   adding: meow/watering_hole1042_.jpg (deflated 1%)
#   adding: meow/volcano900_.jpg (deflated 2%)
#   adding: meow/orchard675_.jpg (deflated 1%)
#   adding: meow/railroad_track1193_.jpg (deflated 1%)
#   adding: meow/beach_house710_.jpg (deflated 1%)
#   adding: meow/office_building726_.jpg (deflated 1%)
#   adding: meow/elevator_shaft1012_.jpg (deflated 1%)
#   adding: meow/snowfield454_.jpg (deflated 1%)
#   adding: meow/coast497_.jpg (deflated 2%)
#   adding: meow/assembly_line528_.jpg (deflated 1%)
#   adding: meow/beach97_.jpg (deflated 5%)
#   adding: meow/baseball_field630_.jpg (deflated 1%)
#   adding: meow/artists_loft516_.jpg (deflated 1%)
#   adding: meow/embassy319_.jpg (deflated 1%)
#   adding: meow/lighthouse420_.jpg (deflated 2%)
#   adding: meow/roof_garden156_.jpg (deflated 1%)
#   adding: meow/coast495_.jpg (deflated 2%)
#   adding: meow/house1263_.jpg (deflated 1%)
#   adding: meow/canyon621_.jpg (deflated 2%)
#   adding: meow/fishpond674_.jpg (deflated 1%)
#   adding: meow/swimming_hole1457_.jpg (deflated 1%)
#   adding: meow/ski_resort1315_.jpg (deflated 2%)
#   adding: meow/mausoleum480_.jpg (deflated 1%)
#   adding: meow/banquet_hall1464_.jpg (deflated 1%)
#   adding: meow/car_interior365_.jpg (deflated 2%)
#   adding: meow/harbor136_.jpg (deflated 2%)
#   adding: meow/sauna765_.jpg (deflated 1%)
#   adding: meow/restaurant_kitchen1403_.jpg (deflated 1%)
#   adding: meow/ocean_deep109_.jpg (deflated 1%)
#   adding: meow/water_park165_.jpg (deflated 1%)
#   adding: meow/excavation915_.jpg (deflated 1%)
#   adding: meow/islet564_.jpg (deflated 2%)
#   adding: meow/utility_room1173_.jpg (deflated 1%)
#   adding: meow/restaurant_kitchen1401_.jpg (deflated 1%)
#   adding: meow/lawn236_.jpg (deflated 1%)
#   adding: meow/natural_history_museum1149_.jpg (deflated 1%)
#   adding: meow/wild262_.jpg (deflated 1%)
#   adding: meow/corridor939_.jpg (deflated 3%)
#   adding: meow/beer_garden1049_.jpg (deflated 1%)
#   adding: meow/wave476_.jpg (deflated 1%)
#   adding: meow/slum148_.jpg (deflated 1%)
#   adding: meow/valley554_.jpg (deflated 1%)
#   adding: meow/slum146_.jpg (deflated 2%)
#   adding: meow/swimming_hole1460_.jpg (deflated 1%)
#   adding: meow/patio1532_.jpg (deflated 1%)
#   adding: meow/sand404_.jpg (deflated 1%)
#   adding: meow/fire_escape913_.jpg (deflated 1%)
#   adding: meow/courtyard31_.jpg (deflated 1%)
#   adding: meow/ice_cream_parlor1321_.jpg (deflated 1%)
#   adding: meow/interior744_.jpg (deflated 2%)
#   adding: meow/alley337_.jpg (deflated 1%)
#   adding: meow/shop406_.jpg (deflated 1%)
#   adding: meow/aquarium600_.jpg (deflated 1%)
#   adding: meow/japanese_garden947_.jpg (deflated 1%)
#   adding: meow/wheat_field1103_.jpg (deflated 1%)
#   adding: meow/football611_.jpg (deflated 1%)
#   adding: meow/igloo1478_.jpg (deflated 1%)
#   adding: meow/tundra1268_.jpg (deflated 1%)
#   adding: meow/cafeteria1440_.jpg (deflated 1%)
#   adding: meow/delicatessen1222_.jpg (deflated 1%)
#   adding: meow/tower1350_.jpg (deflated 3%)
#   adding: meow/airplane_cabin869_.jpg (deflated 1%)
#   adding: meow/ocean250_.jpg (deflated 2%)
#   adding: meow/field_road818_.jpg (deflated 1%)
#   adding: meow/shoe_shop1177_.jpg (deflated 1%)
#   adding: meow/sandbox111_.jpg (deflated 1%)
#   adding: meow/glacier1428_.jpg (deflated 2%)
#   adding: meow/tower1348_.jpg (deflated 2%)
#   adding: meow/childs_room661_.jpg (deflated 1%)
#   adding: meow/heliport1291_.jpg (deflated 1%)
#   adding: meow/alley338_.jpg (deflated 1%)
#   adding: meow/harbor138_.jpg (deflated 3%)
#   adding: meow/butte17_.jpg (deflated 1%)
#   adding: meow/boathouse1520_.jpg (deflated 1%)
#   adding: meow/racecourse211_.jpg (deflated 1%)
#   adding: meow/artists_loft515_.jpg (deflated 1%)
#   adding: meow/dining_room1092_.jpg (deflated 1%)
#   adding: meow/forest_path1431_.jpg (deflated 1%)
#   adding: meow/racecourse213_.jpg (deflated 1%)
#   adding: meow/supermarket697_.jpg (deflated 1%)
#   adding: meow/orchard678_.jpg (deflated 1%)
#   adding: meow/auto_showroom1336_.jpg (deflated 2%)
#   adding: meow/wind_farm241_.jpg (deflated 1%)
#   adding: meow/bedroom1054_.jpg (deflated 2%)
#   adding: meow/car_interior366_.jpg (deflated 1%)
#   adding: meow/clothing_store1237_.jpg (deflated 1%)
#   adding: meow/biology_laboratory1409_.jpg (deflated 1%)
#   adding: meow/tower1349_.jpg (deflated 1%)
#   adding: meow/house1262_.jpg (deflated 1%)
#   adding: meow/bowling_alley2_.jpg (deflated 1%)
#   adding: meow/patio1531_.jpg (deflated 1%)
#   adding: meow/butchers_shop855_.jpg (deflated 1%)
#   adding: meow/parking_lot386_.jpg (deflated 1%)
#   adding: meow/berth1126_.jpg (deflated 2%)
#   adding: meow/playroom25_.jpg (deflated 1%)
#   adding: meow/watering_hole1044_.jpg (deflated 1%)
#   adding: meow/auditorium1547_.jpg (deflated 2%)
#   adding: meow/biology_laboratory1408_.jpg (deflated 1%)
#   adding: meow/pagoda984_.jpg (deflated 3%)
#   adding: meow/martial_arts_gym762_.jpg (deflated 1%)
#   adding: meow/jail_cell824_.jpg (deflated 3%)
#   adding: meow/toyshop63_.jpg (deflated 1%)
#   adding: meow/wet_bar300_.jpg (deflated 1%)
#   adding: meow/downtown394_.jpg (deflated 1%)
#   adding: meow/watering_hole1041_.jpg (deflated 2%)
#   adding: meow/tree_house1166_.jpg (deflated 1%)
#   adding: meow/server_room708_.jpg (deflated 1%)
#   adding: meow/music_studio862_.jpg (deflated 2%)
#   adding: meow/assembly_line526_.jpg (deflated 1%)
#   adding: meow/aquarium604_.jpg (deflated 2%)
#   adding: meow/oast_house1421_.jpg (deflated 1%)
#   adding: meow/manufactured_home324_.jpg (deflated 2%)
#   adding: meow/catacomb844_.jpg (deflated 1%)
#   adding: meow/plaza1390_.jpg (deflated 1%)
#   adding: meow/lobby1500_.jpg (deflated 1%)
#   adding: meow/plaza1389_.jpg (deflated 1%)
#   adding: meow/restaurant_kitchen1404_.jpg (deflated 1%)
#   adding: meow/drugstore429_.jpg (deflated 1%)
#   adding: meow/orchestra_pit721_.jpg (deflated 1%)
#   adding: meow/palace163_.jpg (deflated 1%)
#   adding: meow/chemistry_lab990_.jpg (deflated 1%)
#   adding: meow/conference_center1022_.jpg (deflated 1%)
#   adding: meow/indoor1242_.jpg (deflated 1%)
#   adding: meow/nursery643_.jpg (deflated 1%)
#   adding: meow/amusement_park14_.jpg (deflated 1%)
#   adding: meow/cemetery1185_.jpg (deflated 1%)
#   adding: meow/archive1515_.jpg (deflated 1%)
#   adding: meow/conference_room1568_.jpg (deflated 2%)
#   adding: meow/badlands1538_.jpg (deflated 1%)
#   adding: meow/boardwalk971_.jpg (deflated 2%)
#   adding: meow/auto_showroom1338_.jpg (deflated 6%)
#   adding: meow/football612_.jpg (deflated 1%)
#   adding: meow/chemistry_lab991_.jpg (deflated 1%)
#   adding: meow/art_school1196_.jpg (deflated 2%)
#   adding: meow/food_court785_.jpg (deflated 1%)
#   adding: meow/car_interior369_.jpg (deflated 1%)
#   adding: meow/auditorium1546_.jpg (deflated 5%)
#   adding: meow/gift_shop58_.jpg (deflated 1%)
#   adding: meow/ticket_booth140_.jpg (deflated 1%)
#   adding: meow/art_studio259_.jpg (deflated 1%)
#   adding: meow/runway217_.jpg (deflated 1%)
#   adding: meow/hotel_room1273_.jpg (deflated 1%)
#   adding: meow/water_tower184_.jpg (deflated 3%)
#   adding: meow/marsh1558_.jpg (deflated 1%)
#   adding: meow/forest_road342_.jpg (deflated 2%)
#   adding: meow/aqueduct75_.jpg (deflated 1%)
#   adding: meow/ocean254_.jpg (deflated 1%)
#   adding: meow/pier534_.jpg (deflated 1%)
#   adding: meow/alcove438_.jpg (deflated 2%)
#   adding: meow/television_studio745_.jpg (deflated 1%)
#   adding: meow/promenade1393_.jpg (deflated 1%)
#   adding: meow/watering_hole1040_.jpg (deflated 1%)
#   adding: meow/airplane_cabin865_.jpg (deflated 1%)
#   adding: meow/slum147_.jpg (deflated 1%)
#   adding: meow/industrial_area93_.jpg (deflated 1%)
#   adding: meow/gas_station583_.jpg (deflated 1%)
#   adding: meow/restaurant_patio1288_.jpg (deflated 1%)
#   adding: meow/closet1451_.jpg (deflated 2%)
#   adding: meow/roof_garden159_.jpg (deflated 1%)
#   adding: meow/residential_neighborhood8_.jpg (deflated 1%)
#   adding: meow/tree_farm1035_.jpg (deflated 1%)
#   adding: meow/boathouse1516_.jpg (deflated 1%)
#   adding: meow/galley66_.jpg (deflated 1%)
#   adding: meow/department_store273_.jpg (deflated 1%)
#   adding: meow/elevator_shaft1014_.jpg (deflated 1%)
#   adding: meow/japanese_garden945_.jpg (deflated 2%)
#   adding: meow/mezzanine88_.jpg (deflated 1%)
#   adding: meow/rodeo1375_.jpg (deflated 2%)
#   adding: meow/supermarket695_.jpg (deflated 1%)
#   adding: meow/classroom1303_.jpg (deflated 1%)
#   adding: meow/living_room851_.jpg (deflated 1%)
#   adding: meow/home_office979_.jpg (deflated 2%)
#   adding: meow/driveway449_.jpg (deflated 1%)
#   adding: meow/cafeteria1439_.jpg (deflated 1%)
#   adding: meow/exterior354_.jpg (deflated 3%)
#   adding: meow/campsite871_.jpg (deflated 1%)
#   adding: meow/glacier1427_.jpg (deflated 2%)
#   adding: meow/department_store274_.jpg (deflated 1%)
#   adding: meow/bathroom1019_.jpg (deflated 2%)
#   adding: meow/veterinarians_office1354_.jpg (deflated 1%)
#   adding: meow/airport_terminal1345_.jpg (deflated 1%)
#   adding: meow/orchard677_.jpg (deflated 1%)
#   adding: meow/pagoda981_.jpg (deflated 1%)
#   adding: meow/harbor139_.jpg (deflated 1%)
#   adding: meow/mountain_snowy666_.jpg (deflated 1%)
#   adding: meow/conference_room1567_.jpg (deflated 1%)
#   adding: meow/wild261_.jpg (deflated 1%)
#   adding: meow/desert_road1508_.jpg (deflated 1%)
#   adding: meow/ski_resort1312_.jpg (deflated 1%)
#   adding: meow/arch933_.jpg (deflated 1%)
#   adding: meow/pasture1079_.jpg (deflated 1%)
#   adding: meow/fastfood_restaurant1277_.jpg (deflated 1%)
#   adding: meow/locker_room178_.jpg (deflated 4%)
#   adding: meow/gas_station580_.jpg (deflated 1%)
#   adding: meow/army_base540_.jpg (deflated 1%)
#   adding: meow/phone_booth568_.jpg (deflated 1%)
#   adding: meow/coffee_shop71_.jpg (deflated 2%)
#   adding: meow/storage_room102_.jpg (deflated 2%)
#   adding: meow/excavation916_.jpg (deflated 1%)
#   adding: meow/palace161_.jpg (deflated 1%)
#   adding: meow/ruin501_.jpg (deflated 1%)
#   adding: meow/mansion284_.jpg (deflated 1%)
#   adding: meow/ice_floe37_.jpg (deflated 2%)
#   adding: meow/ice_shelf1080_.jpg (deflated 1%)
#   adding: meow/oast_house1422_.jpg (deflated 1%)
#   adding: meow/crosswalk1131_.jpg (deflated 1%)
#   adding: meow/storage_room103_.jpg (deflated 1%)
#   adding: meow/natural334_.jpg (deflated 1%)
#   adding: meow/conference_center1024_.jpg (deflated 1%)
#   adding: meow/fastfood_restaurant1279_.jpg (deflated 1%)
#   adding: meow/corn_field1524_.jpg (deflated 1%)
#   adding: meow/pet_shop898_.jpg (deflated 1%)
#   adding: meow/street125_.jpg (deflated 1%)
#   adding: meow/pagoda983_.jpg (deflated 1%)
#   adding: meow/discotheque1299_.jpg (deflated 2%)
#   adding: meow/ice_shelf1083_.jpg (deflated 2%)
#   adding: meow/chemistry_lab992_.jpg (deflated 1%)
#   adding: meow/desert_road1506_.jpg (deflated 2%)
#   adding: meow/gift_shop56_.jpg (deflated 1%)
#   adding: meow/snowfield453_.jpg (deflated 2%)
#   adding: meow/ski_resort1314_.jpg (deflated 1%)
#   adding: meow/racecourse212_.jpg (deflated 1%)
#   adding: meow/ball_pit1160_.jpg (deflated 1%)
#   adding: meow/aquarium603_.jpg (deflated 1%)
#   adding: meow/stable1482_.jpg (deflated 1%)
#   adding: meow/water692_.jpg (deflated 1%)
#   adding: meow/junkyard814_.jpg (deflated 1%)
#   adding: meow/dining_room1091_.jpg (deflated 1%)
#   adding: meow/vineyard470_.jpg (deflated 2%)
#   adding: meow/ticket_booth143_.jpg (deflated 1%)
#   adding: meow/highway1369_.jpg (deflated 1%)
#   adding: meow/office_cubicles208_.jpg (deflated 1%)
#   adding: meow/tree_house1168_.jpg (deflated 1%)
#   adding: meow/runway218_.jpg (deflated 2%)
#   adding: meow/indoor1241_.jpg (deflated 1%)
#   adding: meow/ocean_deep108_.jpg (deflated 3%)
#   adding: meow/auto_factory357_.jpg (deflated 1%)
#   adding: meow/beauty_salon578_.jpg (deflated 1%)
#   adding: meow/assembly_line525_.jpg (deflated 1%)
#   adding: meow/pet_shop897_.jpg (deflated 2%)
#   adding: meow/highway1370_.jpg (deflated 1%)
#   adding: meow/japanese_garden946_.jpg (deflated 1%)
#   adding: meow/fire_station1413_.jpg (deflated 1%)
#   adding: meow/butchers_shop856_.jpg (deflated 1%)
#   adding: meow/arcade796_.jpg (deflated 1%)
#   adding: meow/legislative_chamber364_.jpg (deflated 1%)
#   adding: meow/loading_dock1203_.jpg (deflated 1%)
#   adding: meow/vegetation227_.jpg (deflated 2%)
#   adding: meow/courtyard34_.jpg (deflated 1%)
#   adding: meow/ticket_booth141_.jpg (deflated 1%)
#   adding: meow/banquet_hall1461_.jpg (deflated 1%)
#   adding: meow/broadleaf592_.jpg (deflated 1%)
#   adding: meow/toyshop60_.jpg (deflated 1%)
#   adding: meow/hardware_store1211_.jpg (deflated 1%)
#   adding: meow/restaurant_patio1290_.jpg (deflated 1%)
#   adding: meow/supermarket698_.jpg (deflated 1%)
#   adding: meow/forest_road343_.jpg (deflated 1%)
#   adding: meow/mountain_path759_.jpg (deflated 2%)
#   adding: meow/broadleaf593_.jpg (deflated 1%)
#   adding: meow/house1265_.jpg (deflated 1%)
#   adding: meow/castle616_.jpg (deflated 1%)
#   adding: meow/zen_garden1089_.jpg (deflated 1%)
#   adding: meow/art_gallery830_.jpg (deflated 2%)
#   adding: meow/elevator_lobby1033_.jpg (deflated 1%)
#   adding: meow/tower1346_.jpg (deflated 3%)
#   adding: meow/kasbah349_.jpg (deflated 2%)
#   adding: meow/field_road815_.jpg (deflated 1%)
#   adding: meow/orchestra_pit720_.jpg (deflated 2%)
#   adding: meow/embassy318_.jpg (deflated 1%)
#   adding: meow/aqueduct79_.jpg (deflated 1%)
#   adding: meow/schoolhouse1071_.jpg (deflated 2%)
#   adding: meow/yard508_.jpg (deflated 1%)
#   adding: meow/stable1484_.jpg (deflated 2%)
#   adding: meow/manufactured_home320_.jpg (deflated 1%)
#   adding: meow/dressing_room82_.jpg (deflated 1%)
#   adding: meow/door1333_.jpg (deflated 2%)
#   adding: meow/stable1485_.jpg (deflated 1%)
#   adding: meow/candy_store588_.jpg (deflated 1%)
#   adding: meow/picnic_area719_.jpg (deflated 1%)
#   adding: meow/runway219_.jpg (deflated 1%)
#   adding: meow/golf_course1364_.jpg (deflated 1%)
#   adding: meow/soccer_field1306_.jpg (deflated 1%)
#   adding: meow/boxing_ring555_.jpg (deflated 2%)
#   adding: meow/carrousel382_.jpg (deflated 1%)
#   adding: meow/farm1000_.jpg (deflated 1%)
#   adding: meow/home_theater1329_.jpg (deflated 3%)
#   adding: meow/art_school1198_.jpg (deflated 1%)
#   adding: meow/farm1002_.jpg (deflated 2%)
#   adding: meow/burial_chamber116_.jpg (deflated 1%)
#   adding: meow/army_base541_.jpg (deflated 1%)
#   adding: meow/beer_garden1046_.jpg (deflated 1%)
#   adding: meow/nursing_home1443_.jpg (deflated 2%)
#   adding: meow/fabric_store1122_.jpg (deflated 1%)
#   adding: meow/auto_showroom1340_.jpg (deflated 1%)
#   adding: meow/construction_site966_.jpg (deflated 1%)
#   adding: meow/recreation_room289_.jpg (deflated 1%)
#   adding: meow/mezzanine87_.jpg (deflated 2%)
#   adding: meow/trench188_.jpg (deflated 1%)
#   adding: meow/lagoon908_.jpg (deflated 3%)
#   adding: meow/lobby1498_.jpg (deflated 1%)
#   adding: meow/volcano902_.jpg (deflated 1%)
#   adding: meow/sandbox113_.jpg (deflated 1%)
#   adding: meow/topiary_garden731_.jpg (deflated 1%)
#   adding: meow/youth_hostel294_.jpg (deflated 1%)
#   adding: meow/landfill468_.jpg (deflated 1%)
#   adding: meow/racecourse214_.jpg (deflated 2%)
#   adding: meow/alcove439_.jpg (deflated 1%)
#   adding: meow/pasture1076_.jpg (deflated 1%)
#   adding: meow/vegetable_garden1097_.jpg (deflated 1%)
#   adding: meow/pharmacy1418_.jpg (deflated 2%)
#   adding: meow/basement650_.jpg (deflated 1%)
#   adding: meow/palace164_.jpg (deflated 1%)
#   adding: meow/sky1116_.jpg (deflated 1%)
#   adding: meow/drugstore427_.jpg (deflated 1%)
#   adding: meow/phone_booth569_.jpg (deflated 3%)
#   adding: meow/beauty_salon579_.jpg (deflated 1%)
#   adding: meow/food_court787_.jpg (deflated 1%)
#   adding: meow/sand403_.jpg (deflated 3%)
#   adding: meow/barndoor1144_.jpg (deflated 1%)
#   adding: meow/residential_neighborhood9_.jpg (deflated 1%)
#   adding: meow/iceberg1501_.jpg (deflated 2%)
#   adding: meow/canyon620_.jpg (deflated 1%)
#   adding: meow/boxing_ring559_.jpg (deflated 1%)
#   adding: meow/train_interior922_.jpg (deflated 1%)
#   adding: meow/aquarium602_.jpg (deflated 1%)
#   adding: meow/recreation_room285_.jpg (deflated 1%)
#   adding: meow/rope_bridge1544_.jpg (deflated 1%)
#   adding: meow/porch964_.jpg (deflated 1%)
#   adding: meow/office1260_.jpg (deflated 1%)
#   adding: meow/urban828_.jpg (deflated 1%)
#   adding: meow/hospital884_.jpg (deflated 1%)
#   adding: meow/barndoor1143_.jpg (deflated 1%)
#   adding: meow/pantry838_.jpg (deflated 1%)
#   adding: meow/office1259_.jpg (deflated 1%)
#   adding: meow/hot_spring488_.jpg (deflated 2%)
#   adding: meow/airfield1449_.jpg (deflated 2%)
#   adding: meow/arcade795_.jpg (deflated 1%)
#   adding: meow/water690_.jpg (deflated 1%)
#   adding: meow/airport_terminal1341_.jpg (deflated 1%)
#   adding: meow/lobby1499_.jpg (deflated 2%)
#   adding: meow/conference_center1023_.jpg (deflated 1%)
#   adding: meow/park1376_.jpg (deflated 1%)
#   adding: meow/amusement_park12_.jpg (deflated 1%)
#   adding: meow/racecourse210_.jpg (deflated 6%)
#   adding: meow/closet1453_.jpg (deflated 2%)
#   adding: meow/valley551_.jpg (deflated 1%)
#   adding: meow/gas_station582_.jpg (deflated 1%)
#   adding: meow/playground1151_.jpg (deflated 1%)
#   adding: meow/plaza1386_.jpg (deflated 1%)
#   adding: meow/bathroom1015_.jpg (deflated 1%)
#   adding: meow/kindergarden_classroom848_.jpg (deflated 1%)
#   adding: meow/patio1535_.jpg (deflated 1%)
#   adding: meow/cliff130_.jpg (deflated 1%)
#   adding: meow/crosswalk1133_.jpg (deflated 1%)
#   adding: meow/crosswalk1130_.jpg (deflated 1%)
#   adding: meow/berth1129_.jpg (deflated 3%)
#   adding: meow/ball_pit1164_.jpg (deflated 2%)
#   adding: meow/playground1153_.jpg (deflated 1%)
#   adding: meow/cafeteria1438_.jpg (deflated 1%)
#   adding: meow/castle617_.jpg (deflated 1%)
#   adding: meow/golf_course1362_.jpg (deflated 1%)
#   adding: meow/door1334_.jpg (deflated 1%)
#   adding: meow/staircase47_.jpg (deflated 1%)
#   adding: meow/coast498_.jpg (deflated 2%)
#   adding: meow/archaelogical_excavation192_.jpg (deflated 1%)
#   adding: meow/reception1247_.jpg (deflated 1%)
#   adding: meow/landfill467_.jpg (deflated 1%)
#   adding: meow/water_tower183_.jpg (deflated 4%)
#   adding: meow/urban829_.jpg (deflated 3%)
#   adding: meow/formal_garden657_.jpg (deflated 1%)
#   adding: meow/aquarium601_.jpg (deflated 1%)
#   adding: meow/toyshop64_.jpg (deflated 1%)
#   adding: meow/legislative_chamber363_.jpg (deflated 2%)
#   adding: meow/pier530_.jpg (deflated 2%)
#   adding: meow/drugstore426_.jpg (deflated 1%)
#   adding: meow/rope_bridge1542_.jpg (deflated 2%)
#   adding: meow/auditorium1549_.jpg (deflated 1%)
#   adding: meow/soccer_field1309_.jpg (deflated 1%)
#   adding: meow/wind_farm244_.jpg (deflated 4%)
#   adding: meow/boardwalk972_.jpg (deflated 1%)
#   adding: meow/asia494_.jpg (deflated 1%)
#   adding: meow/engine_room782_.jpg (deflated 1%)
#   adding: meow/kitchen1358_.jpg (deflated 2%)
#   adding: meow/rodeo1372_.jpg (deflated 1%)
#   adding: meow/tundra1269_.jpg (deflated 2%)
#   adding: meow/archaelogical_excavation191_.jpg (deflated 1%)
#   adding: meow/fountain52_.jpg (deflated 1%)
#   adding: meow/pantry835_.jpg (deflated 1%)
#   adding: meow/auto_factory358_.jpg (deflated 1%)
#   adding: meow/wild264_.jpg (deflated 2%)
#   adding: meow/nursery641_.jpg (deflated 3%)
#   adding: meow/soccer_field1310_.jpg (deflated 1%)
#   adding: meow/beer_hall545_.jpg (deflated 1%)
#   adding: meow/catacomb840_.jpg (deflated 1%)
#   adding: meow/amusement_park10_.jpg (deflated 1%)
#   adding: meow/water_tower182_.jpg (deflated 3%)
#   adding: meow/banquet_hall1465_.jpg (deflated 1%)
#   adding: meow/lobby1496_.jpg (deflated 1%)
#   adding: meow/football613_.jpg (deflated 1%)
#   adding: meow/nursery642_.jpg (deflated 2%)
#   adding: meow/lecture_room266_.jpg (deflated 1%)
#   adding: meow/performance1551_.jpg (deflated 2%)
#   adding: meow/utility_room1174_.jpg (deflated 3%)
#   adding: meow/lock_chamber1114_.jpg (deflated 1%)
#   adding: meow/schoolhouse1072_.jpg (deflated 1%)
#   adding: meow/home_theater1328_.jpg (deflated 2%)
#   adding: meow/heliport1292_.jpg (deflated 1%)
#   adding: meow/wet_bar302_.jpg (deflated 1%)
#   adding: meow/fire_escape910_.jpg (deflated 1%)
#   adding: meow/army_base542_.jpg (deflated 1%)
#   adding: meow/hockey440_.jpg (deflated 1%)
#   adding: meow/parking_lot387_.jpg (deflated 1%)
#   adding: meow/pharmacy1417_.jpg (deflated 1%)
#   adding: meow/lobby1497_.jpg (deflated 1%)
#   adding: meow/pharmacy1420_.jpg (deflated 1%)
#   adding: meow/manufactured_home322_.jpg (deflated 2%)
#   adding: meow/fire_escape914_.jpg (deflated 1%)
#   adding: meow/waterfall1561_.jpg (deflated 1%)
#   adding: meow/baseball_field633_.jpg (deflated 1%)
#   adding: meow/lighthouse421_.jpg (deflated 2%)
#   adding: meow/loading_dock1200_.jpg (deflated 2%)
#   adding: meow/mezzanine89_.jpg (deflated 1%)
#   adding: meow/hospital_room150_.jpg (deflated 2%)
#   adding: meow/mountain1529_.jpg (deflated 2%)
#   adding: meow/wave478_.jpg (deflated 1%)
#   adding: meow/laundromat1489_.jpg (deflated 1%)
#   adding: meow/plaza1387_.jpg (deflated 1%)
#   adding: meow/creek775_.jpg (deflated 1%)
#   adding: meow/hardware_store1210_.jpg (deflated 1%)
#   adding: meow/dining_hall464_.jpg (deflated 1%)
#   adding: meow/fishpond673_.jpg (deflated 1%)
#   adding: meow/lawn239_.jpg (deflated 1%)
#   adding: meow/cultivated800_.jpg (deflated 1%)
#   adding: meow/building_facade1230_.jpg (deflated 1%)
#   adding: meow/downtown390_.jpg (deflated 1%)
#   adding: meow/cockpit1181_.jpg (deflated 1%)
#   adding: meow/clean_room326_.jpg (deflated 2%)
#   adding: meow/stable1481_.jpg (deflated 1%)
#   adding: meow/nursery644_.jpg (deflated 2%)
#   adding: meow/rope_bridge1545_.jpg (deflated 1%)
#   adding: meow/discotheque1298_.jpg (deflated 2%)
#   adding: meow/outdoor1108_.jpg (deflated 1%)
#   adding: meow/dining_room1090_.jpg (deflated 1%)
#   adding: meow/exterior352_.jpg (deflated 1%)
#   adding: meow/television_studio746_.jpg (deflated 1%)
#   adding: meow/plaza1388_.jpg (deflated 1%)
#   adding: meow/ocean253_.jpg (deflated 3%)
#   adding: meow/tree_farm1037_.jpg (deflated 6%)
#   adding: meow/landing_deck1205_.jpg (deflated 1%)
#   adding: meow/soccer609_.jpg (deflated 1%)
#   adding: meow/topiary_garden730_.jpg (deflated 2%)
#   adding: meow/airport_terminal1344_.jpg (deflated 1%)
#   adding: meow/mezzanine86_.jpg (deflated 1%)
#   adding: meow/reception1248_.jpg (deflated 1%)
#   adding: meow/fire_escape912_.jpg (deflated 1%)
#   adding: meow/alley339_.jpg (deflated 1%)
#   adding: meow/embassy317_.jpg (deflated 1%)
#   adding: meow/medina1468_.jpg (deflated 2%)
#   adding: meow/hockey442_.jpg (deflated 1%)
#   adding: meow/playroom29_.jpg (deflated 1%)
#   adding: meow/staircase45_.jpg (deflated 1%)
#   adding: meow/engine_room780_.jpg (deflated 1%)
#   adding: meow/building_facade1234_.jpg (deflated 2%)
#   adding: meow/storage_room101_.jpg (deflated 1%)
#   adding: meow/football_field1066_.jpg (deflated 1%)
#   adding: meow/medina1469_.jpg (deflated 1%)
#   adding: meow/shopfront418_.jpg (deflated 1%)
#   adding: meow/vegetation225_.jpg (deflated 1%)
#   adding: meow/patio1534_.jpg (deflated 1%)
#   adding: meow/railroad_track1192_.jpg (deflated 1%)
#   adding: meow/manufactured_home321_.jpg (deflated 1%)
#   adding: meow/dorm_room704_.jpg (deflated 2%)
#   adding: meow/heliport1294_.jpg (deflated 4%)
#   adding: meow/rock_arch396_.jpg (deflated 1%)
#   adding: meow/bridge520_.jpg (deflated 2%)
#   adding: meow/pharmacy1419_.jpg (deflated 1%)
#   adding: meow/picnic_area716_.jpg (deflated 1%)
#   adding: meow/waterfall1563_.jpg (deflated 1%)
#   adding: meow/train_interior924_.jpg (deflated 1%)
#   adding: meow/delicatessen1220_.jpg (deflated 1%)
#   adding: meow/office_cubicles206_.jpg (deflated 1%)
#   adding: meow/orchard679_.jpg (deflated 1%)
#   adding: meow/drugstore425_.jpg (deflated 1%)
#   adding: meow/snowfield452_.jpg (deflated 2%)
#   adding: meow/physics_laboratory1027_.jpg (deflated 1%)
#   adding: meow/corral957_.jpg (deflated 2%)
#   adding: meow/rainforest1492_.jpg (deflated 1%)
#   adding: meow/amphitheater877_.jpg (deflated 1%)
#   adding: meow/server_room705_.jpg (deflated 1%)
#   adding: meow/bus_interior1320_.jpg (deflated 1%)
#   adding: meow/swamp295_.jpg (deflated 1%)
#   adding: meow/vegetation229_.jpg (deflated 1%)
#   adding: meow/creek778_.jpg (deflated 1%)
#   adding: meow/archaelogical_excavation193_.jpg (deflated 1%)
#   adding: meow/boathouse1518_.jpg (deflated 2%)
#   adding: meow/campsite873_.jpg (deflated 1%)
#   adding: meow/barn891_.jpg (deflated 1%)
#   adding: meow/wild260_.jpg (deflated 1%)
#   adding: meow/attic1283_.jpg (deflated 1%)
#   adding: meow/water691_.jpg (deflated 1%)
#   adding: meow/shoe_shop1175_.jpg (deflated 1%)
#   adding: meow/server_room707_.jpg (deflated 1%)
#   adding: meow/dining_room1094_.jpg (deflated 1%)
#   adding: meow/indoor1245_.jpg (deflated 1%)
#   adding: meow/waiting_room374_.jpg (deflated 2%)
#   adding: meow/ocean252_.jpg (deflated 2%)
#   adding: meow/pet_shop899_.jpg (deflated 1%)
#   adding: meow/rice_paddy1225_.jpg (deflated 1%)
#   adding: meow/hot_spring487_.jpg (deflated 1%)
#   adding: meow/mausoleum483_.jpg (deflated 1%)
#   adding: meow/art_studio257_.jpg (deflated 1%)
#   adding: meow/amusement_arcade987_.jpg (deflated 1%)
#   adding: meow/islet561_.jpg (deflated 5%)
#   adding: meow/ice_cream_parlor1322_.jpg (deflated 3%)
#   adding: meow/street126_.jpg (deflated 1%)
#   adding: meow/residential_neighborhood5_.jpg (deflated 1%)
#   adding: meow/desert_road1507_.jpg (deflated 2%)
#   adding: meow/elevator_lobby1031_.jpg (deflated 2%)
#   adding: meow/ballroom648_.jpg (deflated 1%)
#   adding: meow/ruin502_.jpg (deflated 1%)
#   adding: meow/airplane_cabin868_.jpg (deflated 1%)
#   adding: meow/beer_hall547_.jpg (deflated 1%)
#   adding: meow/marsh1556_.jpg (deflated 1%)
#   adding: meow/swamp299_.jpg (deflated 1%)
#   adding: meow/catacomb841_.jpg (deflated 1%)
#   adding: meow/candy_store587_.jpg (deflated 1%)
#   adding: meow/pet_shop896_.jpg (deflated 1%)
#   adding: meow/department_store272_.jpg (deflated 1%)
#   adding: meow/gas_station584_.jpg (deflated 5%)
#   adding: meow/wet_bar301_.jpg (deflated 3%)
#   adding: meow/hospital_room153_.jpg (deflated 1%)
#   adding: meow/performance1553_.jpg (deflated 1%)
#   adding: meow/cockpit1182_.jpg (deflated 2%)
#   adding: meow/tundra1270_.jpg (deflated 1%)
#   adding: meow/performance1554_.jpg (deflated 2%)
#   adding: meow/urban825_.jpg (deflated 2%)
#   adding: meow/interior741_.jpg (deflated 1%)
#   adding: meow/snowfield451_.jpg (deflated 1%)
#   adding: meow/bus_interior1318_.jpg (deflated 1%)
#   adding: meow/galley68_.jpg (deflated 1%)
#   adding: meow/forest_path1434_.jpg (deflated 1%)
#   adding: meow/oilrig683_.jpg (deflated 1%)
#   adding: meow/trench186_.jpg (deflated 1%)
#   adding: meow/recreation_room287_.jpg (deflated 1%)
#   adding: meow/conference_room1570_.jpg (deflated 1%)
#   adding: meow/arcade798_.jpg (deflated 1%)
#   adding: meow/lecture_room268_.jpg (deflated 1%)
#   adding: meow/medina1470_.jpg (deflated 1%)
#   adding: meow/football_field1065_.jpg (deflated 1%)
#   adding: meow/zen_garden1088_.jpg (deflated 1%)
#   adding: meow/iceberg1503_.jpg (deflated 2%)
#   adding: meow/tower1347_.jpg (deflated 1%)
#   adding: meow/pond513_.jpg (deflated 2%)
#   adding: meow/raft997_.jpg (deflated 1%)
#   adding: meow/kindergarden_classroom845_.jpg (deflated 1%)
#   adding: meow/butchers_shop857_.jpg (deflated 1%)
#   adding: meow/staircase46_.jpg (deflated 1%)
#   adding: meow/mountain_path758_.jpg (deflated 2%)
#   adding: meow/landing_deck1207_.jpg (deflated 2%)
#   adding: meow/cockpit1180_.jpg (deflated 1%)
#   adding: meow/harbor135_.jpg (deflated 1%)
#   adding: meow/public944_.jpg (deflated 1%)
#   adding: meow/corn_field1523_.jpg (deflated 1%)
#   adding: meow/youth_hostel291_.jpg (deflated 2%)
#   adding: meow/arch932_.jpg (deflated 1%)
#   adding: meow/hockey443_.jpg (deflated 1%)
#   adding: meow/runway215_.jpg (deflated 1%)
#   adding: meow/clean_room325_.jpg (deflated 2%)
#   adding: meow/fabric_store1123_.jpg (deflated 1%)
#   adding: meow/sandbox110_.jpg (deflated 1%)
#   adding: meow/music_studio861_.jpg (deflated 1%)
#   adding: meow/auto_factory359_.jpg (deflated 1%)
#   adding: meow/snowfield450_.jpg (deflated 2%)
#   adding: meow/sushi_bar1400_.jpg (deflated 1%)
#   adding: meow/badlands1539_.jpg (deflated 2%)
#   adding: meow/alley335_.jpg (deflated 1%)
#   adding: meow/oilrig681_.jpg (deflated 3%)
#   adding: meow/water_park168_.jpg (deflated 1%)
#   adding: meow/mountain1530_.jpg (deflated 4%)
#   adding: meow/carrousel380_.jpg (deflated 2%)
#   adding: meow/windmill927_.jpg (deflated 1%)
#   adding: meow/grotto574_.jpg (deflated 1%)
#   adding: meow/home_office977_.jpg (deflated 1%)
#   adding: meow/dressing_room83_.jpg (deflated 2%)
#   adding: meow/cemetery1186_.jpg (deflated 1%)
#   adding: meow/bank_vault1064_.jpg (deflated 1%)
#   adding: meow/forest_path1435_.jpg (deflated 1%)
#   adding: meow/auditorium1550_.jpg (deflated 1%)
#   adding: meow/swimming_hole1458_.jpg (deflated 1%)
#   adding: meow/vineyard471_.jpg (deflated 1%)
#   adding: meow/shed597_.jpg (deflated 1%)
#   adding: meow/platform627_.jpg (deflated 1%)
#   adding: meow/barn890_.jpg (deflated 1%)
#   adding: meow/urban826_.jpg (deflated 1%)
#   adding: meow/baseball752_.jpg (deflated 1%)
#   adding: meow/hayfield806_.jpg (deflated 5%)
#   adding: meow/living_room852_.jpg (deflated 2%)
#   adding: meow/clean_room328_.jpg (deflated 2%)
#   adding: meow/ballroom649_.jpg (deflated 1%)
#   adding: meow/street128_.jpg (deflated 1%)
#   adding: meow/martial_arts_gym760_.jpg (deflated 1%)
#   adding: meow/burial_chamber115_.jpg (deflated 2%)
#   adding: meow/veterinarians_office1353_.jpg (deflated 2%)
#   adding: meow/pier533_.jpg (deflated 1%)
#   adding: meow/sky1119_.jpg (deflated 9%)
#   adding: meow/mezzanine85_.jpg (deflated 1%)
#   adding: meow/skyscraper885_.jpg (deflated 1%)
#   adding: meow/operating_room636_.jpg (deflated 1%)
#   adding: meow/junkyard810_.jpg (deflated 1%)
#   adding: meow/crosswalk1132_.jpg (deflated 32%)
#   adding: meow/clean_room329_.jpg (deflated 1%)
#   adding: meow/boxing_ring556_.jpg (deflated 1%)
#   adding: meow/lock_chamber1113_.jpg (deflated 1%)
#   adding: meow/soccer606_.jpg (deflated 1%)
#   adding: meow/sky1115_.jpg (deflated 6%)
#   adding: meow/picnic_area717_.jpg (deflated 1%)
#   adding: meow/dressing_room80_.jpg (deflated 1%)
#   adding: meow/fishpond670_.jpg (deflated 1%)
#   adding: meow/gift_shop55_.jpg (deflated 1%)
#   adding: meow/topiary_garden734_.jpg (deflated 1%)
#   adding: meow/porch962_.jpg (deflated 1%)
#   adding: meow/amphitheater878_.jpg (deflated 1%)
#   adding: meow/platform628_.jpg (deflated 1%)
#   adding: meow/cliff134_.jpg (deflated 1%)
#   adding: meow/beer_garden1048_.jpg (deflated 1%)
#   adding: meow/hotel_room1275_.jpg (deflated 1%)
#   adding: meow/restaurant1385_.jpg (deflated 1%)
#   adding: meow/glacier1426_.jpg (deflated 2%)
#   adding: meow/ski_slope222_.jpg (deflated 1%)
#   adding: meow/shoe_shop1179_.jpg (deflated 1%)
#   adding: meow/corral955_.jpg (deflated 1%)
#   adding: meow/archive1512_.jpg (deflated 1%)
#   adding: meow/bedchamber1006_.jpg (deflated 1%)
#   adding: meow/waiting_room371_.jpg (deflated 1%)
#   adding: meow/door1335_.jpg (deflated 2%)
#   adding: meow/rice_paddy1227_.jpg (deflated 1%)
#   adding: meow/bridge522_.jpg (deflated 1%)
#   adding: meow/mountain_snowy667_.jpg (deflated 1%)
#   adding: meow/science_museum1475_.jpg (deflated 1%)
# ...
#   adding: meow/dam170_.jpg (deflated 1%)
#   adding: meow/art_studio258_.jpg (deflated 1%)
#   adding: meow/lighthouse423_.jpg (deflated 1%)
#   adding: meow/fabric_store1120_.jpg (deflated 1%)
#   adding: meow/pier531_.jpg (deflated 4%)
#   adding: meow/utility_room1172_.jpg (deflated 2%)
#   adding: meow/playroom27_.jpg (deflated 1%)
#   adding: meow/chalet1059_.jpg (deflated 1%)
#   adding: meow/forest_road344_.jpg (deflated 1%)
#   adding: meow/art_gallery831_.jpg (deflated 1%)
#   adding: meow/attic1285_.jpg (deflated 2%)
#   adding: meow/rice_paddy1228_.jpg (deflated 1%)
#   adding: meow/boxing_ring558_.jpg (deflated 1%)
#   adding: meow/asia490_.jpg (deflated 1%)
#   adding: meow/home_theater1330_.jpg (deflated 3%)
#   adding: meow/art_studio256_.jpg (deflated 1%)
#   adding: meow/alley336_.jpg (deflated 1%)
#   adding: meow/glacier1430_.jpg (deflated 1%)
#   adding: meow/bedchamber1009_.jpg (deflated 1%)
#   adding: meow/banquet_hall1463_.jpg (deflated 1%)
#   adding: meow/driveway445_.jpg (deflated 1%)
#   adding: meow/vineyard472_.jpg (deflated 1%)
#   adding: meow/restaurant_patio1287_.jpg (deflated 1%)
#   adding: meow/indoor1240_.jpg (deflated 1%)
#   adding: meow/pasture1077_.jpg (deflated 1%)
#   adding: meow/art_studio255_.jpg (deflated 1%)
#   adding: meow/iceberg1504_.jpg (deflated 1%)
#   adding: meow/living_room850_.jpg (deflated 2%)
#   adding: meow/baseball750_.jpg (deflated 1%)
#   adding: meow/dining_hall461_.jpg (deflated 1%)
#   adding: meow/bank_vault1062_.jpg (deflated 2%)
#   adding: meow/platform629_.jpg (deflated 2%)
#   adding: meow/crevasse456_.jpg (deflated 1%)
#   adding: meow/bar432_.jpg (deflated 1%)
#   adding: meow/discotheque1297_.jpg (deflated 1%)
#   adding: meow/outdoor1107_.jpg (deflated 1%)
#   adding: meow/bar431_.jpg (deflated 1%)
#   adding: meow/science_museum1474_.jpg (deflated 1%)
#   adding: meow/throne_room793_.jpg (deflated 1%)
#   adding: meow/train_interior923_.jpg (deflated 1%)
#   adding: meow/loading_dock1201_.jpg (deflated 1%)
#   adding: meow/dam171_.jpg (deflated 2%)
#   adding: meow/crevasse457_.jpg (deflated 2%)
#   adding: meow/wind_farm243_.jpg (deflated 1%)
#   adding: meow/kasbah346_.jpg (deflated 2%)
#   adding: meow/fountain50_.jpg (deflated 2%)
#   adding: meow/restaurant1383_.jpg (deflated 1%)
#   adding: meow/phone_booth567_.jpg (deflated 2%)
#   adding: meow/ballroom645_.jpg (deflated 3%)
#   adding: meow/natural332_.jpg (deflated 2%)
#   adding: meow/parking_lot388_.jpg (deflated 2%)
#   adding: meow/outdoor1105_.jpg (deflated 1%)
#   adding: meow/beach_house711_.jpg (deflated 1%)
#   adding: meow/fishpond671_.jpg (deflated 1%)
#   adding: meow/chalet1056_.jpg (deflated 1%)
#   adding: meow/rodeo1373_.jpg (deflated 1%)
#   adding: meow/airport_terminal1343_.jpg (deflated 1%)
#   adding: meow/berth1127_.jpg (deflated 1%)
#   adding: meow/fastfood_restaurant1280_.jpg (deflated 1%)
#   adding: meow/coast496_.jpg (deflated 1%)
#   adding: meow/shop409_.jpg (deflated 1%)
#   adding: meow/office_building728_.jpg (deflated 2%)
#   adding: meow/coffee_shop70_.jpg (deflated 1%)
#   adding: meow/gift_shop59_.jpg (deflated 1%)
#   adding: meow/bowling_alley3_.jpg (deflated 1%)
#   adding: meow/pantry837_.jpg (deflated 1%)
#   adding: meow/platform626_.jpg (deflated 2%)
#   adding: meow/shoe_shop1176_.jpg (deflated 2%)
#   adding: meow/forest_road341_.jpg (deflated 1%)
#   adding: meow/ocean_deep107_.jpg (deflated 1%)
#   adding: meow/locker_room176_.jpg (deflated 1%)
#   adding: meow/roof_garden157_.jpg (deflated 1%)
#   adding: meow/picnic_area718_.jpg (deflated 1%)
#   adding: meow/pizzeria234_.jpg (deflated 1%)
#   adding: meow/islet563_.jpg (deflated 3%)
#   adding: meow/beach95_.jpg (deflated 3%)
#   adding: meow/highway1367_.jpg (deflated 1%)
#   adding: meow/cemetery1188_.jpg (deflated 2%)
#   adding: meow/boathouse1519_.jpg (deflated 1%)
#   adding: meow/beach98_.jpg (deflated 3%)
#   adding: meow/promenade1391_.jpg (deflated 2%)
#   adding: meow/conference_center1020_.jpg (deflated 1%)
#   adding: meow/arcade797_.jpg (deflated 1%)
#   adding: meow/river247_.jpg (deflated 3%)
#   adding: meow/badlands1536_.jpg (deflated 1%)
#   adding: meow/kitchen1356_.jpg (deflated 1%)
#   adding: meow/excavation918_.jpg (deflated 1%)
#   adding: meow/natural330_.jpg (deflated 2%)
#   adding: meow/pizzeria231_.jpg (deflated 1%)
#   adding: meow/supermarket696_.jpg (deflated 1%)
#   adding: meow/amusement_arcade986_.jpg (deflated 1%)
#   adding: meow/barn893_.jpg (deflated 1%)
#   adding: meow/industrial_area90_.jpg (deflated 1%)
#   adding: meow/lawn238_.jpg (deflated 1%)
#   adding: meow/mountain1526_.jpg (deflated 5%)
#   adding: meow/artists_loft518_.jpg (deflated 1%)
#   adding: meow/bullring120_.jpg (deflated 1%)
#   adding: meow/vegetable_garden1095_.jpg (deflated 1%)
#   adding: meow/bridge521_.jpg (deflated 2%)
#   adding: meow/oast_house1423_.jpg (deflated 1%)
#   adding: meow/chalet1055_.jpg (deflated 1%)
#   adding: meow/natural_history_museum1148_.jpg (deflated 1%)
#   adding: meow/tree_farm1039_.jpg (deflated 1%)
#   adding: meow/hospital882_.jpg (deflated 1%)
#   adding: meow/locker_room179_.jpg (deflated 1%)
#   adding: meow/lawn237_.jpg (deflated 1%)
#   adding: meow/clothing_store1235_.jpg (deflated 1%)
#   adding: meow/coast499_.jpg (deflated 2%)
#   adding: meow/restaurant1382_.jpg (deflated 1%)
#   adding: meow/mausoleum482_.jpg (deflated 2%)
#   adding: meow/nursery640_.jpg (deflated 1%)
#   adding: meow/bamboo_forest375_.jpg (deflated 1%)
#   adding: meow/courthouse951_.jpg (deflated 1%)
#   adding: meow/office1256_.jpg (deflated 1%)
#   adding: meow/mountain_path756_.jpg (deflated 1%)
#   adding: meow/shopfront416_.jpg (deflated 1%)
#   adding: meow/creek779_.jpg (deflated 1%)
#   adding: meow/office_cubicles205_.jpg (deflated 1%)
#   adding: meow/shop405_.jpg (deflated 1%)
#   adding: meow/courthouse953_.jpg (deflated 2%)
#   adding: meow/food_court786_.jpg (deflated 1%)
#   adding: meow/ice_shelf1084_.jpg (deflated 2%)
#   adding: meow/ocean251_.jpg (deflated 1%)
#   adding: meow/grotto573_.jpg (deflated 1%)
#   adding: meow/sauna766_.jpg (deflated 2%)
#   adding: meow/slum149_.jpg (deflated 1%)
#   adding: meow/slum145_.jpg (deflated 1%)
#   adding: meow/fishpond672_.jpg (deflated 1%)
#   adding: meow/laundromat1487_.jpg (deflated 1%)
#   adding: meow/pizzeria230_.jpg (deflated 1%)
#   adding: meow/hotel_room1272_.jpg (deflated 2%)
#   adding: meow/motel40_.jpg (deflated 1%)
#   adding: meow/rock_arch397_.jpg (deflated 1%)
#   adding: meow/park1377_.jpg (deflated 1%)
#   adding: meow/viaduct770_.jpg (deflated 1%)
#   adding: meow/formal_garden656_.jpg (deflated 1%)
#   adding: meow/auto_showroom1339_.jpg (deflated 1%)
#   adding: meow/farm1004_.jpg (deflated 1%)
#   adding: meow/office1258_.jpg (deflated 1%)
#   adding: meow/boat_deck688_.jpg (deflated 1%)
#   adding: meow/corral956_.jpg (deflated 1%)
#   adding: meow/mausoleum484_.jpg (deflated 1%)
#   adding: meow/aqueduct78_.jpg (deflated 1%)
#   adding: meow/arch931_.jpg (deflated 1%)
#   adding: meow/amusement_park13_.jpg (deflated 1%)
#   adding: meow/mountain1528_.jpg (deflated 1%)
#   adding: meow/chalet1057_.jpg (deflated 1%)
#   adding: meow/amusement_arcade985_.jpg (deflated 1%)
#   adding: meow/yard509_.jpg (deflated 1%)
#   adding: meow/bookstore314_.jpg (deflated 1%)
#   adding: meow/gift_shop57_.jpg (deflated 1%)
#   adding: meow/campus1156_.jpg (deflated 1%)
#   adding: meow/living_room853_.jpg (deflated 2%)
#   adding: meow/television_room539_.jpg (deflated 1%)
#   adding: meow/art_gallery832_.jpg (deflated 1%)
#   adding: meow/windmill925_.jpg (deflated 3%)
#   adding: meow/courtyard33_.jpg (deflated 1%)
#   adding: meow/beauty_salon575_.jpg (deflated 1%)
#   adding: meow/ice_shelf1082_.jpg (deflated 6%)
#   adding: meow/wheat_field1101_.jpg (deflated 1%)
#   adding: meow/archaelogical_excavation190_.jpg (deflated 1%)
#   adding: meow/beach_house712_.jpg (deflated 1%)
#   adding: meow/throne_room791_.jpg (deflated 1%)
#   adding: meow/wave477_.jpg (deflated 1%)
#   adding: meow/swamp297_.jpg (deflated 2%)
#   adding: meow/laundromat1490_.jpg (deflated 1%)
#   adding: meow/natural_history_museum1147_.jpg (deflated 1%)
#   adding: meow/playground1152_.jpg (deflated 1%)
#   adding: meow/castle615_.jpg (deflated 1%)
#   adding: meow/bank_vault1063_.jpg (deflated 1%)
#   adding: meow/recreation_room286_.jpg (deflated 2%)
#   adding: meow/campus1157_.jpg (deflated 1%)
#   adding: meow/amphitheater876_.jpg (deflated 1%)
#   adding: meow/badlands1540_.jpg (deflated 1%)
#   adding: meow/hospital883_.jpg (deflated 1%)
#   adding: meow/raceway306_.jpg (deflated 1%)
#   adding: meow/dining_room1093_.jpg (deflated 1%)
#   adding: meow/pond514_.jpg (deflated 3%)
#   adding: meow/boxing_ring557_.jpg (deflated 1%)
#   adding: meow/beach99_.jpg (deflated 1%)
#   adding: meow/artists_loft519_.jpg (deflated 1%)
#   adding: meow/stable1483_.jpg (deflated 1%)
#   adding: meow/orchestra_pit724_.jpg (deflated 2%)
#   adding: meow/reception1246_.jpg (deflated 1%)
#   adding: meow/water_park166_.jpg (deflated 1%)
#   adding: meow/rodeo1371_.jpg (deflated 1%)
#   adding: meow/water_tower181_.jpg (deflated 2%)
#   adding: meow/wave475_.jpg (deflated 1%)
#   adding: meow/assembly_line527_.jpg (deflated 1%)
#   adding: meow/palace160_.jpg (deflated 2%)
#   adding: meow/campsite872_.jpg (deflated 1%)
#   adding: meow/art_gallery833_.jpg (deflated 1%)
#   adding: meow/basement651_.jpg (deflated 2%)
#   adding: meow/lighthouse424_.jpg (deflated 2%)
#   adding: meow/biology_laboratory1410_.jpg (deflated 1%)
#   adding: meow/science_museum1471_.jpg (deflated 1%)
#   adding: meow/corral958_.jpg (deflated 1%)
#   adding: meow/pavilion1215_.jpg (deflated 1%)
#   adding: meow/bus_interior1316_.jpg (deflated 1%)
#   adding: meow/botanical_garden198_.jpg (deflated 1%)
#   adding: meow/water_park167_.jpg (deflated 1%)
#   adding: meow/amusement_arcade988_.jpg (deflated 1%)
#   adding: meow/hot_spring489_.jpg (deflated 2%)
#   adding: meow/sauna767_.jpg (deflated 2%)
#   adding: meow/delicatessen1221_.jpg (deflated 1%)
#   adding: meow/attic1282_.jpg (deflated 1%)
#   adding: meow/oilrig680_.jpg (deflated 3%)
#   adding: meow/glacier1429_.jpg (deflated 2%)
#   adding: meow/football_field1067_.jpg (deflated 1%)
#   adding: meow/boat_deck689_.jpg (deflated 1%)
#   adding: meow/marsh1557_.jpg (deflated 1%)
#   adding: meow/ice_shelf1081_.jpg (deflated 1%)
#   adding: meow/delicatessen1223_.jpg (deflated 1%)
#   adding: meow/vegetable_garden1096_.jpg (deflated 1%)
#   adding: meow/embassy316_.jpg (deflated 1%)
#   adding: meow/hospital_room151_.jpg (deflated 1%)
#   adding: meow/hotel_room1271_.jpg (deflated 1%)
#   adding: meow/repair_shop21_.jpg (deflated 1%)
#   adding: meow/corn_field1522_.jpg (deflated 1%)
#   adding: meow/arch930_.jpg (deflated 3%)
#   adding: meow/hospital880_.jpg (deflated 1%)
#   adding: meow/ski_slope221_.jpg (deflated 1%)
#   adding: meow/beauty_salon576_.jpg (deflated 1%)
#   adding: meow/football610_.jpg (deflated 3%)
#   adding: meow/kitchen1357_.jpg (deflated 1%)
#   adding: meow/operating_room637_.jpg (deflated 1%)
#   adding: meow/river245_.jpg (deflated 1%)
#   adding: meow/cultivated803_.jpg (deflated 1%)
#   adding: meow/archive1514_.jpg (deflated 1%)
#   adding: meow/youth_hostel290_.jpg (deflated 2%)
#   adding: meow/throne_room790_.jpg (deflated 2%)
#   adding: meow/childs_room664_.jpg (deflated 1%)
#   adding: meow/promenade1392_.jpg (deflated 2%)
#   adding: meow/jail_cell821_.jpg (deflated 1%)
#   adding: meow/banquet_hall1462_.jpg (deflated 2%)
#   adding: meow/galley69_.jpg (deflated 2%)
#   adding: meow/gas_station581_.jpg (deflated 1%)
#   adding: meow/japanese_garden949_.jpg (deflated 1%)
#   adding: meow/restaurant_patio1289_.jpg (deflated 1%)
#   adding: meow/barndoor1142_.jpg (deflated 1%)
#   adding: meow/mansion282_.jpg (deflated 1%)
#   adding: meow/dressing_room81_.jpg (deflated 2%)
#   adding: meow/locker_room177_.jpg (deflated 1%)
#   adding: meow/construction_site969_.jpg (deflated 1%)
#   adding: meow/hot_spring486_.jpg (deflated 1%)
#   adding: meow/japanese_garden948_.jpg (deflated 1%)
#   adding: meow/pasture1075_.jpg (deflated 1%)
#   adding: meow/ice_cream_parlor1324_.jpg (deflated 1%)
#   adding: meow/promenade1394_.jpg (deflated 1%)
#   adding: meow/pagoda982_.jpg (deflated 1%)
#   adding: meow/raft998_.jpg (deflated 1%)
#   adding: meow/science_museum1473_.jpg (deflated 1%)
#   adding: meow/corridor936_.jpg (deflated 1%)
#   adding: meow/throne_room794_.jpg (deflated 1%)
#   adding: meow/clothing_store1236_.jpg (deflated 1%)
#   adding: meow/driveway448_.jpg (deflated 1%)
#   adding: meow/server_room706_.jpg (deflated 2%)
#   adding: meow/cockpit1183_.jpg (deflated 1%)
#   adding: meow/youth_hostel293_.jpg (deflated 2%)
#   adding: meow/elevator_lobby1034_.jpg (deflated 1%)
#   adding: meow/bedroom1051_.jpg (deflated 1%)
#   adding: meow/courtyard32_.jpg (deflated 1%)
#   adding: meow/public942_.jpg (deflated 1%)
#   adding: meow/marsh1560_.jpg (deflated 1%)
#   adding: meow/construction_site965_.jpg (deflated 1%)
#   adding: meow/galley67_.jpg (deflated 1%)
#   adding: meow/wave479_.jpg (deflated 3%)
#   adding: meow/motel44_.jpg (deflated 2%)
#   adding: meow/farm1001_.jpg (deflated 1%)
#   adding: meow/engine_room781_.jpg (deflated 1%)
#   adding: meow/dining_hall460_.jpg (deflated 1%)
#   adding: meow/sky1117_.jpg (deflated 7%)
#   adding: meow/bank_vault1061_.jpg (deflated 1%)
#   adding: meow/basement652_.jpg (deflated 1%)
#   adding: meow/harbor137_.jpg (deflated 1%)
#   adding: meow/tree_house1169_.jpg (deflated 1%)
#   adding: meow/aqueduct76_.jpg (deflated 1%)
#   adding: meow/sky1118_.jpg (deflated 3%)
#   adding: meow/department_store271_.jpg (deflated 1%)
#   adding: meow/mountain_path757_.jpg (deflated 1%)
#   adding: meow/playground1154_.jpg (deflated 1%)
#   adding: meow/jewelry_shop1252_.jpg (deflated 1%)
#   adding: meow/beer_hall546_.jpg (deflated 1%)
#   adding: meow/water694_.jpg (deflated 1%)
#   adding: meow/vegetation226_.jpg (deflated 2%)
#   adding: meow/closet1454_.jpg (deflated 1%)
#   adding: meow/canyon622_.jpg (deflated 1%)
#   adding: meow/youth_hostel292_.jpg (deflated 2%)
#   adding: meow/bedroom1050_.jpg (deflated 1%)
#   adding: meow/biology_laboratory1406_.jpg (deflated 1%)
#   adding: meow/vineyard473_.jpg (deflated 1%)
#   adding: meow/arch934_.jpg (deflated 2%)
#   adding: meow/railroad_track1191_.jpg (deflated 1%)
#   adding: meow/village737_.jpg (deflated 1%)
#   adding: meow/martial_arts_gym764_.jpg (deflated 1%)
#   adding: meow/sushi_bar1399_.jpg (deflated 1%)
#   adding: meow/fountain53_.jpg (deflated 1%)
#   adding: meow/entrance_hall1136_.jpg (deflated 1%)
#   adding: meow/television_studio747_.jpg (deflated 1%)
#   adding: meow/cemetery1189_.jpg (deflated 2%)
#   adding: meow/marsh1559_.jpg (deflated 1%)
#   adding: meow/courthouse952_.jpg (deflated 1%)
#   adding: meow/boardwalk974_.jpg (deflated 3%)
#   adding: meow/rope_bridge1543_.jpg (deflated 1%)
#   adding: meow/rock_arch395_.jpg (deflated 2%)
#   adding: meow/tree_house1167_.jpg (deflated 1%)
#   adding: meow/pizzeria233_.jpg (deflated 1%)
#   adding: meow/shower200_.jpg (deflated 2%)
#   adding: meow/attic1284_.jpg (deflated 2%)
#   adding: meow/interior742_.jpg (deflated 2%)
#   adding: meow/clean_room327_.jpg (deflated 2%)
#   adding: meow/toyshop61_.jpg (deflated 1%)
#   adding: meow/auto_factory355_.jpg (deflated 1%)
#   adding: meow/viaduct774_.jpg (deflated 1%)
#   adding: meow/bullring121_.jpg (deflated 1%)
#   adding: meow/shop408_.jpg (deflated 1%)
#   adding: meow/bridge523_.jpg (deflated 1%)
#   adding: meow/childs_room662_.jpg (deflated 1%)
#   adding: meow/ski_slope220_.jpg (deflated 1%)
#   adding: meow/topiary_garden733_.jpg (deflated 2%)
#   adding: meow/oilrig682_.jpg (deflated 2%)
#   adding: meow/beach_house713_.jpg (deflated 2%)
#   adding: meow/carrousel381_.jpg (deflated 1%)
#   adding: meow/bullring122_.jpg (deflated 1%)
#   adding: meow/junkyard813_.jpg (deflated 1%)
#   adding: meow/zen_garden1085_.jpg (deflated 1%)
#   adding: meow/staircase49_.jpg (deflated 1%)
#   adding: meow/art_school1199_.jpg (deflated 1%)
#   adding: meow/dining_hall463_.jpg (deflated 1%)
#   adding: meow/building_facade1233_.jpg (deflated 1%)
#   adding: meow/reception1249_.jpg (deflated 1%)
#   adding: meow/discotheque1300_.jpg (deflated 1%)
#   adding: meow/mansion283_.jpg (deflated 1%)
#   adding: meow/chemistry_lab993_.jpg (deflated 1%)
#   adding: meow/restaurant_patio1286_.jpg (deflated 1%)
#   adding: meow/creek777_.jpg (deflated 1%)

# %%
# the custom dataset function
from torch.utils.data import Dataset, DataLoader
import torch
from sklearn.model_selection import train_test_split
import cv2
class inpainting_dataset(Dataset):
  """
  The path must be a PAthLib Path object
  """
  def __init__(self, path, transform = None, split : str = "train"):
    self.path = Path('meow')
    self.transform = transform
    self.imgs =  list(self.path.glob("*.jpg"))
    self.imgs.sort()

    self.path = Path("/content/neww/test_images")
    self.lama_imgs = list(self.path.glob("*.jpg"))
    self.lama_imgs.sort()

    self.path = Path("/content/neww/out_path_rg")
    self.mat_imgs = list(self.path.glob("*.png"))
    self.mat_imgs.sort()

    self.path = Path("/content/neww/masks")
    self.masks = list(self.path.glob("*.jpg"))
    self.masks.sort()

    self.final = []
    for i in self.imgs:
      name = i.as_posix().split("/")[-1].split(".")[0]
      mat_name = "/content/neww/out_path_rg/" + name + ".png"    # for mat we have png format
      lama_name = "/content/neww/test_images/" + name + ".jpg" # for lama we have jpg format
      mask_name = "/content/neww/masks/" + name + ".jpg" # for masks

      if os.path.exists(mat_name) and os.path.exists(lama_name) and os.path.exists(mask_name):
        self.final.append(name)

    print(len(self.final))

    self.train_imgs, self.val_imgs = train_test_split(self.imgs, test_size = 0.3,random_state = 42)
    if split == "train":
      self.imgs = self.train_imgs
    else:
      self.imgs = self.val_imgs

  def __len__(self):
    return len(self.imgs)

  def __getitem__(self, idx): # self.final have onlyu names which will be used to just make the path of imgs
    name = self.final[idx]  # to get the path only

    img_n = "/content/neww/train_images/" + name + ".jpg"  # for image name
    mat = "/content/neww/out_path_rg/" + name + ".png"    # for mat we have png format
    lama = "/content/neww/test_images/" + name + ".jpg" # for lama we have jpg format
    mask = "/content/neww/masks/" + name + ".jpg" # for masks


    img = cv2.imread(img_n)
    img_lama = torch.tensor(cv2.imread(lama))
    mat_img = cv2.imread(mat)

    mask = cv2.imread(mask, cv2.IMREAD_GRAYSCALE)
    _, binary_mk = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

    inv_mask = cv2.bitwise_not(binary_mk)

    img_back = cv2.bitwise_and(img, img, mask=inv_mask)
    img_fg = cv2.bitwise_and(mat_img, mat_img, mask=binary_mk)

    final_mat_img = img_back + img_fg

    return torch.tensor(img), img_lama, torch.tensor(final_mat_img) #i.e. correct image, lama and mat image

# %%
from torchvision import transforms

path = Path("meow")

transform = transforms.Compose([
    transforms.Resize((256,256)),
    transforms.ToTensor()
])

# %%
# making the train and test dataset
train_dataset = inpainting_dataset(path, transform = transform, split = "train")
test_dataset = inpainting_dataset(path, transform = transform, split = "test")
train_dataset, test_dataset
# Out:
# 1571
# 1571
# (<__main__.inpainting_dataset at 0x7866d558c9d0>,
#  <__main__.inpainting_dataset at 0x7866d558d810>)

# %%
# making the dataloaders
train_dataloader = DataLoader(train_dataset, batch_size = 16, shuffle = True)
test_dataloader = DataLoader(test_dataset, batch_size = 16,shuffle = False)
train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7866d558d9f0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7866d558db70>)

# %%
len(train_dataloader)
# Out:
# 69

# %%
# exploringg some data
import matplotlib.pyplot as plt
z = next(iter(train_dataloader))

for i in range (16):
  plt.subplot(4,4,i+1)
  plt.axis("off")
  plt.imshow(z[0][i].detach().numpy())

# %%
# exploringg some data
import matplotlib.pyplot as plt
z = next(iter(train_dataloader))

for i in range (16):
  plt.subplot(4,4,i+1)
  plt.axis("off")
  plt.imshow(z[1][i].detach().numpy())

# %%
# exploringg some data
import matplotlib.pyplot as plt
z = next(iter(train_dataloader))

for i in range (16):
  plt.subplot(4,4,i+1)
  plt.axis("off")
  plt.imshow(z[2][i].detach().numpy())

# %%
img, lama, mat = next(iter(train_dataloader))
plt.subplot(1,3,1)
plt.axis("off")
plt.imshow(img[1].detach().numpy())

plt.subplot(1,3,2)
plt.axis("off")
plt.imshow(lama[1].detach().numpy())

plt.subplot(1,3,3)
plt.axis("off")
plt.imshow(mat[1 ].detach().numpy())
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-57-bc5b720e3431> in <cell line: 1>()
# ----> 1 img, lama, mat = next(iter(train_dataloader))
#       2 plt.subplot(1,3,1)
#       3 plt.axis("off")
#       4 plt.imshow(img[1].detach().numpy())
#       5
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     671     def _next_data(self):
#     672         index = self._next_index()  # may raise StopIteration
# --> 673         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674         if self._pin_memory:
#     675             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-52-8bd77757584a> in __getitem__(self, idx)
#      65     inv_mask = cv2.bitwise_not(binary_mk)
#      66
# ---> 67     img_back = cv2.bitwise_and(img, img, mask=inv_mask)
#      68     img_fg = cv2.bitwise_and(mat_img, mat_img, mask=binary_mk)
#      69
#
# error: OpenCV(4.10.0) /io/opencv/modules/core/src/arithm.cpp:230: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'binary_op'

# %%
# the ensemble model --- PLAIN ONE
import torch
from torch import nn

class EnsembleModel(nn.Module):
  """
  This model will combine the output MAT and LAMA which will be saved in the model folder
  """
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Sequential(
        nn.Conv2d(3, 32, 3, 1, 1),
        nn.LeakyReLU(),
        # nn.MaxPool2d(2),
    )
    self.conv2 = nn.Sequential(
        nn.Conv2d(3, 32, 3, 1, 1),
        nn.LeakyReLU(),
        # nn.MaxPool2d(2),
    )
    self.conv3 = nn.Sequential(
        nn.Conv2d(64, 128, 3, 1, 1),   # dependednt on output of concatenation
        nn.LeakyReLU(),
        # nn.MaxPool2d(2),
    )

    self.in_conv3 = nn.Sequential(
        nn.ConvTranspose2d(128, 64, 3, 1, 1),   # dependednt on output of concatenation
        nn.LeakyReLU(),

        nn.ConvTranspose2d(64, 32, 3, 1, 1),   # dependednt on output of concatenation
        nn.LeakyReLU(),

        nn.ConvTranspose2d(32, 3, 3, 1, 1),   # dependednt on output of concatenation
        nn.LeakyReLU(),
    )


  def forward(self, img1, img2):
    x = self.conv1(img1)
    y = self.conv2(img2)
    z = torch.cat((x, y), dim=1)
    z = self.conv3(z)
    z = self.in_conv3(z)
    return z

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the NN architecture
class ConvDenoiser(nn.Module):
    def __init__(self):
        super(ConvDenoiser, self).__init__()
        ## encoder layers ##
        # conv layer (depth from 1 --> 32), 3x3 kernels
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        # conv layer (depth from 32 --> 16), 3x3 kernels
        self.conv2 = nn.Conv2d(32, 16, 3, padding=1)
        # conv layer (depth from 16 --> 8), 3x3 kernels
        self.conv3 = nn.Conv2d(16, 8, 3, padding=1)
        # pooling layer to reduce x-y dims by two; kernel and stride of 2
        # self.pool = nn.MaxPool2d(2, 2)

        ## decoder layers ##
        # transpose layer, a kernel of 2 and a stride of 2 will increase the spatial dims by 2
        # self.t_conv1 = nn.ConvTranspose2d(8, 8, 3, stride=2)  # kernel_size=3 to get to a 7x7 image output
        # two more transpose layers with a kernel of 2
        self.t_conv2 = nn.ConvTranspose2d(8, 16, 3, stride=1)
        self.t_conv3 = nn.ConvTranspose2d(16, 32, 3, stride=1)
        # one, final, normal conv layer to decrease the depth
        self.conv_out = nn.Conv2d(32, 3, 3, padding=1)


    def forward(self, x):
        ## encode ##
        # add hidden layers with relu activation function
        # and maxpooling after
        x = F.relu(self.conv1(x))
        # x = self.pool(x)
        # add second hidden layer
        x = F.relu(self.conv2(x))
        # x = self.pool(x)
        # add third hidden layer
        x = F.relu(self.conv3(x))
        # x = self.pool(x)  # compressed representation

        ## decode ##
        # add transpose conv layers, with relu activation function
        # x = F.relu(self.t_conv1(x))
        x = F.relu(self.t_conv2(x))
        x = F.relu(self.t_conv3(x))
        # transpose again, output should have a sigmoid applied
        x = F.sigmoid(self.conv_out(x))

        return x

denoise = ConvDenoiser()

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the NN architecture
class ConvDenoiser(nn.Module):
    def __init__(self):
        super(ConvDenoiser, self).__init__()
        ## encoder layers ##
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)  # Conv layer (3 --> 32 channels)
        self.conv2 = nn.Conv2d(32, 16, 3, padding=1)  # Conv layer (32 --> 16 channels)
        self.conv3 = nn.Conv2d(16, 8, 3, padding=1)  # Conv layer (16 --> 8 channels)

        ## decoder layers ##
        # Transpose layers to upsample back to the original input size
        self.t_conv1 = nn.ConvTranspose2d(8, 16, 3, padding=1)  # upsample by stride 1, no change in spatial dim
        self.t_conv2 = nn.ConvTranspose2d(16, 32, 3, padding=1)  # upsample by stride 1, no change in spatial dim
        self.t_conv3 = nn.ConvTranspose2d(32, 3, 3, padding=1)  # Output back to 3 channels

    def forward(self, x):
        ## encode ##
        x = F.leaky_relu(self.conv1(x))  # First conv layer
        x = F.leaky_relu(self.conv2(x))  # Second conv layer
        x = F.leaky_relu(self.conv3(x))  # Third conv layer

        ## decode ##
        x = F.leaky_relu(self.t_conv1(x))  # First transpose conv
        x = F.leaky_relu(self.t_conv2(x))  # Second transpose conv
        x = torch.sigmoid(self.t_conv3(x))  # Output layer with sigmoid activation

        return x

# Instantiate the model
denoise = ConvDenoiser()

# %%
# !pip install -q torchinfo

# %%
from torchinfo import summary
import torch
# Create an input tensor with the correct dimensions
input_tensor = torch.randn(16, 3, 256, 256)

# Pass the input tensor to denoise()
out = denoise(input_tensor)
out.shape
# Out:
# torch.Size([16, 3, 256, 256])

# %%
# the loss function utility
import os
import torch
from collections import OrderedDict
from torch import nn as nn
from torchvision.models import vgg as vgg

class Registry():
    """
    The registry that provides name -> object mapping, to support third-party
    users' custom modules.

    To create a registry (e.g. a backbone registry):

    .. code-block:: python

        BACKBONE_REGISTRY = Registry('BACKBONE')

    To register an object:

    .. code-block:: python

        @BACKBONE_REGISTRY.register()
        class MyBackbone():
            ...

    Or:

    .. code-block:: python

        BACKBONE_REGISTRY.register(MyBackbone)
    """

    def __init__(self, name):
        """
        Args:
            name (str): the name of this registry
        """
        self._name = name
        self._obj_map = {}

    def _do_register(self, name, obj):
        assert (name not in self._obj_map), (f"An object named '{name}' was already registered "
                                             f"in '{self._name}' registry!")
        self._obj_map[name] = obj

    def register(self, obj=None):
        """
        Register the given object under the the name `obj.__name__`.
        Can be used as either a decorator or not.
        See docstring of this class for usage.
        """
        if obj is None:
            # used as a decorator
            def deco(func_or_class):
                name = func_or_class.__name__
                self._do_register(name, func_or_class)
                return func_or_class

            return deco

        # used as a function call
        name = obj.__name__
        self._do_register(name, obj)

    def get(self, name):
        ret = self._obj_map.get(name)
        if ret is None:
            raise KeyError(f"No object named '{name}' found in '{self._name}' registry!")
        return ret

    def __contains__(self, name):
        return name in self._obj_map

    def __iter__(self):
        return iter(self._obj_map.items())

    def keys(self):
        return self._obj_map.keys()


DATASET_REGISTRY = Registry('dataset')
ARCH_REGISTRY = Registry('arch')
MODEL_REGISTRY = Registry('model')
LOSS_REGISTRY = Registry('loss')
METRIC_REGISTRY = Registry('metric')

VGG_PRETRAIN_PATH = 'experiments/pretrained_models/vgg19-dcbb9e9d.pth'
NAMES = {
    'vgg11': [
        'conv1_1', 'relu1_1', 'pool1', 'conv2_1', 'relu2_1', 'pool2', 'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2',
        'pool3', 'conv4_1', 'relu4_1', 'conv4_2', 'relu4_2', 'pool4', 'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2',
        'pool5'
    ],
    'vgg13': [
        'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1', 'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',
        'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'pool3', 'conv4_1', 'relu4_1', 'conv4_2', 'relu4_2', 'pool4',
        'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2', 'pool5'
    ],
    'vgg16': [
        'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1', 'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',
        'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'conv3_3', 'relu3_3', 'pool3', 'conv4_1', 'relu4_1', 'conv4_2',
        'relu4_2', 'conv4_3', 'relu4_3', 'pool4', 'conv5_1', 'relu5_1', 'conv5_2', 'relu5_2', 'conv5_3', 'relu5_3',
        'pool5'
    ],
    'vgg19': [
        'conv1_1', 'relu1_1', 'conv1_2', 'relu1_2', 'pool1', 'conv2_1', 'relu2_1', 'conv2_2', 'relu2_2', 'pool2',
        'conv3_1', 'relu3_1', 'conv3_2', 'relu3_2', 'conv3_3', 'relu3_3', 'conv3_4', 'relu3_4', 'pool3', 'conv4_1',
        'relu4_1', 'conv4_2', 'relu4_2', 'conv4_3', 'relu4_3', 'conv4_4', 'relu4_4', 'pool4', 'conv5_1', 'relu5_1',
        'conv5_2', 'relu5_2', 'conv5_3', 'relu5_3', 'conv5_4', 'relu5_4', 'pool5'
    ]
}


def insert_bn(names):
    """Insert bn layer after each conv.

    Args:
        names (list): The list of layer names.

    Returns:
        list: The list of layer names with bn layers.
    """
    names_bn = []
    for name in names:
        names_bn.append(name)
        if 'conv' in name:
            position = name.replace('conv', '')
            names_bn.append('bn' + position)
    return names_bn


@ARCH_REGISTRY.register()
class VGGFeatureExtractor(nn.Module):
    """VGG network for feature extraction.

    In this implementation, we allow users to choose whether use normalization
    in the input feature and the type of vgg network. Note that the pretrained
    path must fit the vgg type.

    Args:
        layer_name_list (list[str]): Forward function returns the corresponding
            features according to the layer_name_list.
            Example: {'relu1_1', 'relu2_1', 'relu3_1'}.
        vgg_type (str): Set the type of vgg network. Default: 'vgg19'.
        use_input_norm (bool): If True, normalize the input image. Importantly,
            the input feature must in the range [0, 1]. Default: True.
        range_norm (bool): If True, norm images with range [-1, 1] to [0, 1].
            Default: False.
        requires_grad (bool): If true, the parameters of VGG network will be
            optimized. Default: False.
        remove_pooling (bool): If true, the max pooling operations in VGG net
            will be removed. Default: False.
        pooling_stride (int): The stride of max pooling operation. Default: 2.
    """

    def __init__(self,
                 layer_name_list,
                 vgg_type='vgg19',
                 use_input_norm=True,
                 range_norm=False,
                 requires_grad=False,
                 remove_pooling=False,
                 pooling_stride=2):
        super(VGGFeatureExtractor, self).__init__()

        self.layer_name_list = layer_name_list
        self.use_input_norm = use_input_norm
        self.range_norm = range_norm

        self.names = NAMES[vgg_type.replace('_bn', '')]
        if 'bn' in vgg_type:
            self.names = insert_bn(self.names)

        # only borrow layers that will be used to avoid unused params
        max_idx = 0
        for v in layer_name_list:
            idx = self.names.index(v)
            if idx > max_idx:
                max_idx = idx

        if os.path.exists(VGG_PRETRAIN_PATH):
            vgg_net = getattr(vgg, vgg_type)(pretrained=False)
            state_dict = torch.load(VGG_PRETRAIN_PATH, map_location=lambda storage, loc: storage)
            vgg_net.load_state_dict(state_dict)
        else:
            vgg_net = getattr(vgg, vgg_type)(pretrained=True)

        features = vgg_net.features[:max_idx + 1]

        modified_net = OrderedDict()
        for k, v in zip(self.names, features):
            if 'pool' in k:
                # if remove_pooling is true, pooling operation will be removed
                if remove_pooling:
                    continue
                else:
                    # in some cases, we may want to change the default stride
                    modified_net[k] = nn.MaxPool2d(kernel_size=2, stride=pooling_stride)
            else:
                modified_net[k] = v

        self.vgg_net = nn.Sequential(modified_net).to(device)

        if not requires_grad:
            self.vgg_net.eval()
            for param in self.parameters():
                param.requires_grad = False
        else:
            self.vgg_net.train()
            for param in self.parameters():
                param.requires_grad = True

        if self.use_input_norm:
            # the mean is for image with range [0, 1]
            self.register_buffer('mean', torch.Tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1).to(device))
            # the std is for image with range [0, 1]
            self.register_buffer('std', torch.Tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1).to(device))

    def forward(self, x):
        """Forward function.

        Args:
            x (Tensor): Input tensor with shape (n, c, h, w).

        Returns:
            Tensor: Forward results.
        """
        if self.range_norm:
            x = (x + 1) / 2
        if self.use_input_norm:
            x = (x - self.mean) / self.std
        output = {}

        for key, layer in self.vgg_net._modules.items():
            x = layer(x)
            if key in self.layer_name_list:
                output[key] = x.clone()

        return output

# %%
# actual loss function
import torch.nn.functional as F

class StyleLoss(nn.Module):

    def __init__(self):
        super(StyleLoss, self).__init__()

    def gram_matrix(self,input):
      a, b, c, d = input.size()  # a=batch size(=1)
      # b=number of feature maps
      # (c,d)=dimensions of a f. map (N=c*d)

      features = input.contiguous().view(a * b, c * d)  # resize F_XL into \hat F_XL

      G = torch.mm(features, features.t())  # compute the gram product

      # we 'normalize' the values of the gram matrix
      # by dividing by the number of element in each feature maps.
      return G.div(a * b * c * d)

    def forward(self, input, target1):
        G = self.gram_matrix(input)
        target = self.gram_matrix(target1).detach()
        self.loss = F.mse_loss(G, target)
        return self.loss

class PerceptualLoss(nn.Module):
    """Perceptual loss with commonly used style loss.

    Args:
        layer_weights (dict): The weight for each layer of vgg feature.
            Here is an example: {'conv5_4': 1.}, which means the conv5_4
            feature layer (before relu5_4) will be extracted with weight
            1.0 in calculting losses.
        vgg_type (str): The type of vgg network used as feature extractor.
            Default: 'vgg19'.
        use_input_norm (bool):  If True, normalize the input image in vgg.
            Default: True.
        range_norm (bool): If True, norm images with range [-1, 1] to [0, 1].
            Default: False.
      """

    def __init__(self,
                 layer_weights = {'conv1_2': 1, 'conv2_2': 1,'conv3_4': 1,'conv4_4': 1},
                 vgg_type='vgg19',
                 use_input_norm=True,
                 range_norm=True):
        super(PerceptualLoss, self).__init__()
        self.layer_weights = layer_weights
        self.vgg = VGGFeatureExtractor(
            layer_name_list=list(self.layer_weights.keys()),
            vgg_type=vgg_type,
            use_input_norm=use_input_norm,
            range_norm=range_norm)

        self.criterion = torch.nn.L1Loss()

    def forward(self, x, gt):
        """Forward function.

        Args:
            x (Tensor): Input tensor with shape (n, c, h, w).
            gt (Tensor): Ground-truth tensor with shape (n, c, h, w).

        Returns:
            Tensor: Forward results.
        """
        # extract vgg features
        x_features = self.vgg(x)
        gt_features = self.vgg(gt.detach())

        # calculate perceptual loss
        percep_loss = 0
        for k in x_features.keys():
            percep_loss += self.criterion(x_features[k], gt_features[k]) * self.layer_weights[k]

        return percep_loss


# def l1_loss():   -> take direct from premade
#   pass

class EdgeLoss(nn.Module):
    def __init__(self, reduction='mean'):
        super(EdgeLoss, self).__init__()
        k = torch.Tensor([[.05, .25, .4, .25, .05]])
        self.kernel = torch.matmul(k.t(),k).unsqueeze(0).repeat(3,1,1,1).to(device)

    def conv_gauss(self, img):
        n_channels, _, kw, kh = self.kernel.shape
        img = F.pad(img, (kw//2, kh//2, kw//2, kh//2), mode='replicate')
        return F.conv2d(img, self.kernel, groups=n_channels)

    def laplacian_kernel(self, current):
        filtered    = self.conv_gauss(current)
        down        = filtered[:,:,::2,::2]
        new_filter  = torch.zeros_like(filtered)
        new_filter[:,:,::2,::2] = down*4
        filtered    = self.conv_gauss(new_filter)
        diff = current - filtered
        return diff

    def forward(self, x, y):
        loss = F.mse_loss(self.laplacian_kernel(x), self.laplacian_kernel(y))
        return loss

class CombinedLoss(nn.Module):
    def __init__(self, device = "cpu"):
        super(CombinedLoss, self).__init__()
        self.edge_loss = EdgeLoss().to(device)
        self.mse_loss = nn.MSELoss().to(device)  # l1 loss
        self.style_loss = StyleLoss().to(device)
        self.perceptual_loss = PerceptualLoss().to(device)

    def forward(self, gen_img, gt_img):
        gen_img.to(device)
        gt_img.to(device)
        edge_loss_value = self.edge_loss(gen_img, gt_img)
        mse_loss_value = self.mse_loss(gen_img, gt_img)
        style_loss_value = self.style_loss(gen_img, gt_img)
        perceptual_loss_value = self.perceptual_loss(gen_img, gt_img)
        total_loss = edge_loss_value + mse_loss_value + style_loss_value + perceptual_loss_value
        return total_loss

# %% [markdown]
# #Training the LAMA denoising model

# %%
# initialize the NN
denoising_model = ConvDenoiser()
criterion = nn.MSELoss()
device = "cuda" if torch.cuda.is_available() else "cpu"

# specify loss function
denoising_optimizer = torch.optim.Adam(denoising_model.parameters(), lr=0.001)

# %%
# actual training
from sklearn.metrics import accuracy_score,mean_absolute_error, mean_squared_error
from tqdm.auto import tqdm

NUM_EPOCHS = 5

denoising_model.to(device)

print(type(denoising_model))
for epoch in tqdm(range(NUM_EPOCHS)):
  train_loss = 0
  denoising_model.train()
  for num,(img, lama, mat) in tqdm(enumerate(train_dataloader)):
    img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)

    pred = denoising_model(lama)

    loss = criterion(pred, img/255.0)  # for RGB color space
    train_loss += loss.item()

    denoising_optimizer.zero_grad()
    loss.backward()
    denoising_optimizer.step()

  test_loss = 0
  denoising_model.eval()
  with torch.inference_mode():
    for num ,(img, lama, mat) in tqdm(enumerate(test_dataloader)):
      img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)

      pred = denoising_model(lama)
      loss = criterion(pred, img/255.0)

      test_loss += loss.item()

  test_loss /= len(test_dataloader)
  train_loss /= len(train_dataloader)

  if epoch%1 == 0:
    torch.save(denoising_model, f"denoising_model_epoch_{epoch}.pth")
    print(f'\nepoch : {epoch} || train loss : {train_loss} || test loss : {test_loss}')
# Out:
# <class '__main__.ConvDenoiser'>
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 0 || train loss : 0.020577056367495437 || test loss : 0.010528662432493134
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 1 || train loss : 0.011211578879596257 || test loss : 0.009880687766285106
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 2 || train loss : 0.010763512090666266 || test loss : 0.009668546485375951
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 3 || train loss : 0.01056875723027965 || test loss : 0.010054153570143337
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 4 || train loss : 0.010307887430507236 || test loss : 0.009554035173178736

# %% [markdown]
# # training the denoising model on output of ensembler

# %%
print("hlo")
# Out:
# hlo

# %%
# training hyperparams
from torch.optim import Adam
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

model = EnsembleModel()
model = torch.load("best_unet_with_denois.pth").to(device)
model.to(device)

denoising_model = ConvDenoiser()
denoising_model_lama = torch.load("denoising_model_good.pth")

loss_fn = nn.MSELoss()

denoising_optimizer = torch.optim.Adam(denoising_model.parameters(), lr=0.001)
# Out:
# <ipython-input-51-b8b79b75c2a3>:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load("best_unet_with_denois.pth").to(device)
# <ipython-input-51-b8b79b75c2a3>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   denoising_model_lama = torch.load("denoising_model_good.pth")

# %%
# actual training
from sklearn.metrics import accuracy_score,mean_absolute_error, mean_squared_error
from tqdm.auto import tqdm

NUM_EPOCHS = 5

model.to(device)
denoising_model.to(device)
denoising_model_lama.to(device)

model.eval()
denoising_model_lama.eval()

print(type(denoising_model))
for epoch in tqdm(range(NUM_EPOCHS)):
  train_loss = 0
  denoising_model.train()
  for num,(img, lama, mat) in tqdm(enumerate(train_dataloader)):
    img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)

    pred = denoising_model(model(denoising_model_lama(lama), mat))

    loss = loss_fn(pred*255.0, img)  # for RGB color space
    train_loss += loss.item()

    denoising_optimizer.zero_grad()
    loss.backward()
    denoising_optimizer.step()

  test_loss = 0
  denoising_model.eval()
  with torch.inference_mode():
    for num ,(img, lama, mat) in tqdm(enumerate(test_dataloader)):
      img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)

      pred = denoising_model(model(denoising_model_lama(lama), mat))
      loss = loss_fn(pred*255.0, img)

      test_loss += loss.item()

  test_loss /= len(test_dataloader)
  train_loss /= len(train_dataloader)

  if epoch%1 == 0:
    torch.save(model, f"model_epoch_{epoch}.pth")
    print(f'\nepoch : {epoch} || train loss : {train_loss} || test loss : {test_loss}')
# Out:
# <class '__main__.ConvDenoiser'>
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 0 || train loss : 61.30586110556998 || test loss : 111.45435853437944
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 1 || train loss : 59.68726345155297 || test loss : 54.77767866308039
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 2 || train loss : 55.165857817487016 || test loss : 54.85136738690463
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 3 || train loss : 46.866142021737446 || test loss : 45.652615157040685
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 4 || train loss : 42.2803336166754 || test loss : 40.065861615267664

# %%
torch.save(denoising_model, 'best_denoising_model_for_final_mf.pth')

# %% [markdown]
# # Training the ensemble model

# %%
! pip install pytorch_ssim
# Out:
# Collecting pytorch_ssim
#   Downloading pytorch_ssim-0.1.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pytorch_ssim
#   Building wheel for pytorch_ssim (setup.py) ... done
#   Created wheel for pytorch_ssim: filename=pytorch_ssim-0.1-py3-none-any.whl size=2007 sha256=829fe915f711f02bae563518d120b32d547ff087f922c29be9e11f2e515bf846
#   Stored in directory: /root/.cache/pip/wheels/2e/0c/10/4a3f91bd610b23196f1e28f8af80b3ec86786b50f3e86dc21e
# Successfully built pytorch_ssim
# Installing collected packages: pytorch_ssim
# Successfully installed pytorch_ssim-0.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np

class SSIMLoss(nn.Module):
    def __init__(self, window_size=11, size_average=True):
        super(SSIMLoss, self).__init__()
        self.window_size = window_size
        self.size_average = size_average
        self.channel = 1  # Can be changed if you're using color images (e.g. 3 for RGB)
        self.window = self.create_window(window_size, self.channel)

    def gaussian_window(self, window_size, sigma):
        gauss = torch.Tensor([np.exp(-(x - window_size//2)**2 / float(2 * sigma**2)) for x in range(window_size)])
        return gauss / gauss.sum()

    def create_window(self, window_size, channel):
        _1D_window = self.gaussian_window(window_size, 1.5).unsqueeze(1)
        _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
        window = Variable(_2D_window.expand(channel, 1, window_size, window_size).contiguous())
        return window

    def _ssim(self, img1, img2, window, window_size, channel, size_average=True):
        mu1 = F.conv2d(img1, window, padding=window_size//2, groups=channel)
        mu2 = F.conv2d(img2, window, padding=window_size//2, groups=channel)

        mu1_sq = mu1 ** 2
        mu2_sq = mu2 ** 2
        mu1_mu2 = mu1 * mu2

        sigma1_sq = F.conv2d(img1 * img1, window, padding=window_size//2, groups=channel) - mu1_sq
        sigma2_sq = F.conv2d(img2 * img2, window, padding=window_size//2, groups=channel) - mu2_sq
        sigma12 = F.conv2d(img1 * img2, window, padding=window_size//2, groups=channel) - mu1_mu2

        C1 = 0.01 ** 2
        C2 = 0.03 ** 2

        ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))

        if size_average:
            return ssim_map.mean()
        else:
            return ssim_map.mean(1).mean(1).mean(1)

    def forward(self, img1, img2):
        (_, channel, _, _) = img1.size()

        if channel == self.channel and self.window.data.type() == img1.data.type():
            window = self.window
        else:
            window = self.create_window(self.window_size, channel)

            if img1.is_cuda:
                window = window.cuda(img1.get_device())
            window = window.type_as(img1)

            self.channel = channel
            self.window = window

        return 1 - self._ssim(img1, img2, window, self.window_size, channel, self.size_average)


# Example Usage:
# Create an instance of the SSIM loss
ssim_loss = SSIMLoss(window_size=11, size_average=True)

# Dummy input tensors (for example, your model output and ground truth image)

z = next(iter(test_dataloader))
ground_truth, lama, mat = z[0][1], z[1][1], z[2][1]

output = model(denoising_model(lama.unsqueeze(0).to(torch.float).permute(0,3,1,2)), mat.unsqueeze(0).to(torch.float).permute(0,3,1,2)).squeeze()

# output = model(denoising_model(lama), mat)  # Example shape: (batch_size, channels, height, width)

# Calculate the SSIM loss
loss = ssim_loss(output.unsqueeze(0).to(torch.uint8), ground_truth.permute(2,0,1).unsqueeze(0).to(torch.uint8))
print(f'SSIM Loss: {loss.item()}')
# Out:
# SSIM Loss: 0.0

# %%
import pytorch_ssim

# Functional: pytorch_ssim.ssim(img1, img2, window_size = 11, size_average = True)
ssim_value = pytorch_ssim.ssim(output.unsqueeze(0).to(torch.uint8), ground_truth.permute(2,0,1).unsqueeze(0).to(torch.uint8)).data[0]
print("Initial ssim:", ssim_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a97a2db3e030> in <cell line: 4>()
#       2
#       3 # Functional: pytorch_ssim.ssim(img1, img2, window_size = 11, size_average = True)
# ----> 4 ssim_value = pytorch_ssim.ssim(output.unsqueeze(0).to(torch.uint8), ground_truth.permute(2,0,1).unsqueeze(0).to(torch.uint8)).data[0]
#       5 print("Initial ssim:", ssim_value)
#
# /usr/local/lib/python3.10/dist-packages/pytorch_ssim/__init__.py in ssim(img1, img2, window_size, size_average)
#      60     (_, channel, _, _) = img1.size()
#      61     window = create_window(window_size, channel)
# ---> 62     return _ssim(img1, img2, window, window_size, channel, size_average)
#
# /usr/local/lib/python3.10/dist-packages/pytorch_ssim/__init__.py in _ssim(img1, img2, window, window_size, channel, size_average)
#      16
#      17 def _ssim(img1, img2, window, window_size, channel, size_average = True):
# ---> 18     mu1 = F.conv2d(img1, window, padding = window_size/2, groups = channel)
#      19     mu2 = F.conv2d(img2, window, padding = window_size/2, groups = channel)
#      20
#
# TypeError: conv2d() received an invalid combination of arguments - got (Tensor, Tensor, groups=int, padding=float), but expected one of:
#  * (Tensor input, Tensor weight, Tensor bias = None, tuple of ints stride = 1, tuple of ints padding = 0, tuple of ints dilation = 1, int groups = 1)
#  * (Tensor input, Tensor weight, Tensor bias = None, tuple of ints stride = 1, str padding = "valid", tuple of ints dilation = 1, int groups = 1)

# %%
# training hyperparams
# OPTIMZER AND OTHER SETTINGS FOR TRAINING
from torch.optim import Adam
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
# loss_fn = CombinedLoss(device = device).to(device)
loss_fn = SSIMLoss()
# rgb_to_hvi = RGB_HVI() another possibilty for modification

model = EnsembleModel()
# model.to(device)
model = torch.load("best_unet_with_denois.pth", map_location=torch.device('cpu')) #.to(device)

optimizer = Adam(model.parameters(), lr=1e-4)
denoising_model = torch.load("denoising_model_good.pth", map_location=torch.device('cpu'))
# Out:
# <ipython-input-25-931368ac12df>:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load("best_unet_with_denois.pth", map_location=torch.device('cpu')) #.to(device)
# <ipython-input-25-931368ac12df>:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   denoising_model = torch.load("denoising_model_good.pth", map_location=torch.device('cpu'))

# %%
# actual training
from sklearn.metrics import accuracy_score,mean_absolute_error, mean_squared_error
from tqdm.auto import tqdm

NUM_EPOCHS = 5

model.to(device)
denoising_model.to(device)

denoising_model.eval()
print(type(model))
for epoch in tqdm(range(NUM_EPOCHS)):
  train_loss = 0
  model.train()
  for num,(img, lama, mat) in tqdm(enumerate(train_dataloader)):
    img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)

    pred = denoising_model(model(denoising_model(lama), mat))

    loss = loss_fn(pred, img)  # for RGB color space
    train_loss += loss.item()

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  test_loss = 0
  model.eval()
  with torch.inference_mode():
    for num ,(img, lama, mat) in tqdm(enumerate(test_dataloader)):
      img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)

      pred = denoising_model(model(denoising_model(lama), mat))
      loss = loss_fn(pred, img)

      test_loss += loss.item()

  test_loss /= len(test_dataloader)
  train_loss /= len(train_dataloader)

  if epoch%1 == 0:
    torch.save(model, f"model_epoch_{epoch}.pth")
    print(f'\nepoch : {epoch} || train loss : {train_loss} || test loss : {test_loss}')
# Out:
# <class '__main__.EnsembleModel'>
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 0 || train loss : 105436.66749237805 || test loss : 108585.57834694603
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# epoch : 1 || train loss : 104983.95150533537 || test loss : 108583.87215909091
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-e57f6f0c51f4> in <cell line: 12>()
#      14   model.train()
#      15   for num,(img, lama, mat) in tqdm(enumerate(train_dataloader)):
# ---> 16     img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)
#      17
#      18     pred = denoising_model(model(denoising_model(lama), mat))
#
# KeyboardInterrupt:

# %%
pred
# Out:
# tensor([[[0.4133, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0508, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#        grad_fn=<SqueezeBackward0>)

# %%
torch.save(model, 'best_unet_with_denois12.pth')

# %%
torch.save(denoising_model, 'denoising_model_good.pth')

# %%
model = torch.load("best_unet_with_denois.pth")
denoising_model = torch.load('best_final_denoiser_10epochs.pth')
denoising_model_lama = torch.load("denoising_model_good.pth")
# Out:
# <ipython-input-17-3a74ed61a9cf>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load("best_unet_with_denois.pth")
# <ipython-input-17-3a74ed61a9cf>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   denoising_model = torch.load('best_final_denoiser_10epochs.pth')
# <ipython-input-17-3a74ed61a9cf>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   denoising_model_lama = torch.load("denoising_model_good.pth")

# %%
num = 8
z = next(iter(test_dataloader))
gt, lama, mat = z[0][num], z[1][num], z[2][num]

denoising_model_lama.to('cpu')
model.to("cpu")
pred = model(denoising_model_lama(lama.unsqueeze(0).to(torch.float).permute(0,3,1,2)), mat.unsqueeze(0).to(torch.float).permute(0,3,1,2)).squeeze()
pred.shape
# Out:
# torch.Size([3, 256, 256])

# %%
denoising_model.to("cpu")
denoising_model.eval()
lama2 = denoising_model_lama(lama.unsqueeze(0).to(torch.float).permute(0,3,1,2)).squeeze()

plt.figure(figsize=(15,15))
plt.subplot(1,6,1)
plt.imshow((gt/255).detach().numpy())
plt.axis("off")
plt.title("Ground Truth")

plt.subplot(1,6,2)
plt.axis("off")
plt.imshow(lama.detach().numpy())
plt.title("Lama")

plt.subplot(1,6,3)
plt.axis("off")
plt.imshow(mat.detach().numpy())
plt.title("Mat")

plt.subplot(1,6,4)
plt.axis("off")
plt.imshow(lama2.permute(1,2,0).detach().numpy())
plt.title("Denoise LAMA")

plt.subplot(1,6,5)
plt.axis("off")
plt.imshow((pred).to(torch.uint8).permute(1,2,0).detach().numpy())
plt.title("semi Prediction")

plt.subplot(1,6,6)
plt.axis("off")
plt.imshow((denoising_model(pred.unsqueeze(0))*255).to(torch.uint8).squeeze().permute(1,2,0).detach().numpy())
plt.title("Final Prediction")
# Out:
# Text(0.5, 1.0, 'Final Prediction')

# %%
from torchmetrics.image import StructuralSimilarityIndexMeasure

ssim = StructuralSimilarityIndexMeasure(data_range=1.0)
out = ssim(pred.unsqueeze(0).to(torch.float), gt.permute(2,0,1).unsqueeze(0).to(torch.float)).item()
out
# Out:
# 0.9920491576194763

# %%
denoising_model(pred)*255
# Out:
# tensor([[[1.3850e+02, 2.4846e-19, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [2.5458e-19, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [4.6304e-34, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [1.5913e-25, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [5.9737e-22, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [5.7441e-16, 9.1165e-33, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 4.0184e-31]],
#
#         [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [7.0068e-26, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 1.7725e-35]],
#
#         [[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          ...,
#          [1.0481e-19, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [4.1825e-03, 1.3385e-18, 0.0000e+00,  ..., 0.0000e+00,
#           0.0000e+00, 0.0000e+00],
#          [1.7463e+02, 6.4566e+00, 7.4946e-08,  ..., 9.6928e-24,
#           4.3945e-21, 1.2320e-22]]], grad_fn=<MulBackward0>)

# %%
# saving the final model
torch.save(model, "bagging_lama_mat_zero_dce_model.pth")

# %%
torch.save(denoising_model, "best_final_denoiser_10epochs.pth")

# %%
device = 'cuda'

# %%
# finally evaluating the thing
import lpips
from tqdm import tqdm
import numpy as np
from torchmetrics.image import StructuralSimilarityIndexMeasure
from torchmetrics.image.fid import FrechetInceptionDistance
import os
import torch
from torchvision.utils import save_image
denoising_model.to(device)
denoising_model_lama.to(device)
model.to(device)

final_list_0 = []
final_list_1 = []
final_list_2 = []
final_list_3 = []
final_list_4 = []
def eval_model(model_, device, test_dataloader, out_dir):

    metric_fn = lpips.LPIPS(net='alex').to(device)

    # model = HINT(experiment=args.experiment) #calling a model
    model_ = model_.to(device) #puting in gpu
    # model.load_state_dict(torch.load(args.checkpoint_path, map_location=device)) #loading weights

    #get dataloader
    ssim = StructuralSimilarityIndexMeasure(data_range=1.0).to(device)
    # ssim_metric += ssim(image_reconstructed, gt_image).item()
    fid = FrechetInceptionDistance().to(device)

    metric = 0
    ssim_metric = 0
    fid_metric = 0
    metric_list = []
    ssim_metric_list = []
    fid_metric_list = []

    # DCE_net = enhance_net_nopool().to(device)
    # DCE_net.load_state_dict(torch.load('Zero-DCE/Zero-DCE_code/snapshots/Epoch99.pth'))
    model_.eval()
    # DCE_net.eval()

    if not os.path.exists(out_dir):
        # Create a new directory because it does not exist
        os.makedirs(out_dir)

    with tqdm(total=len(test_dataloader), unit_scale=True, postfix={'lpips':0.0,'ssim':0.0, 'fid':0.0}, ncols=150) as pbar:
        for i, (img, lama, mat) in enumerate(test_dataloader):
            img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)
            gt_image = img

            with torch.no_grad():
                lama = denoising_model_lama(lama)
                image_reconstructed = denoising_model(model_(lama, mat))*255.0 # i need to do /255.0
                # the below lines are for using ZERO-DCE
                # _,image_reconstructed,_ = DCE_net(image_reconstructed/255.0)
                # image_reconstructed = image_reconstructed*255

            for j in range(image_reconstructed.shape[0]):
                x = image_reconstructed
                save_image(x[j], out_dir+'/'+ str((2*i)+j) + ".jpg" )


            ssim_metric += ssim((image_reconstructed/255.0), (img/255.0)).item()
            fid.update(torch.tensor(image_reconstructed, dtype=torch.uint8), real = False)
            fid.update(torch.tensor(gt_image, dtype=torch.uint8), real = True)
            fid_metric += fid.compute().item()

            metric += torch.mean(metric_fn(gt_image, image_reconstructed)).item()
            metric_list.append(torch.mean(metric_fn(gt_image, image_reconstructed)).item())
            ssim_metric_list.append(ssim((image_reconstructed/255.0),( gt_image/255.0)).item())
            fid_metric_list.append(fid.compute().item())

            s = ssim(image_reconstructed, gt_image).item()
            if s < 0.6:
              final_list_0.append(img)
              final_list_1.append(lama)
              final_list_2.append(mat )
              final_list_3.append(s)
              final_list_4.append(image_reconstructed)


            pbar.set_postfix({'lpips':metric/(i+1), 'ssim':ssim_metric/(i+1), 'fid' : fid_metric/(i+1)})
            pbar.update(1)

    print('\nLPIPS mean:', np.mean(metric_list))
    print('LPIPS std:', np.std(metric_list))
    print('ssim mean:', np.mean(ssim_metric_list))
    print('ssim std:', np.std(ssim_metric_list))
    print('fid mean:', np.mean(fid_metric_list))
    print('fid std:', np.std(fid_metric_list))

    return metric_list, ssim_metric_list, fid_metric_list

# m = EnsembleModel()
# model2 = torch.load("bagging_lama_mat_model.pth")
# model2 = m.load_state_dict(ldict)

device = 'cuda' if torch.cuda.is_available else "cpu"
metric_list, ssim_metric_list, fid_metric_list = eval_model(model, device, test_dataloader, "outputs")
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.10/dist-packages/lpips/weights/v0.1/alex.pth
# /usr/local/lib/python3.10/dist-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
#   0%|                                                                                             | 0.00/88.0 [00:00<?, ?it/s, fid=0, lpips=0, ssim=0]<ipython-input-126-5616bd14aadc>:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   fid.update(torch.tensor(image_reconstructed, dtype=torch.uint8), real = False)
# <ipython-input-126-5616bd14aadc>:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   fid.update(torch.tensor(gt_image, dtype=torch.uint8), real = True)
# 100%|██████████████████████████████████████████████████████████████████████████| 88.0/88.0 [07:17<00:00, 4.97s/it, lpips=0.0131, ssim=0.969, fid=13.1]
# LPIPS mean: 0.013117557105777616
# LPIPS std: 0.003034066402649222
# ssim mean: 0.9689629416574131
# ssim std: 0.0044811635040028
# fid mean: 13.06565062566237
# fid std: 3.619307175748063

# %%
min(final_list_3)
# Out:
# -0.06728321313858032

# %%
ind = final_list_3.index(min(final_list_3))
img = final_list_0[ind]
lama = final_list_1[ind]
mat = final_list_2[ind]
reco = final_list_4[ind]

# plt.imshow(img.permute(1,2,0).cpu().detach().numpy())

# %%
img[0].dtype, reco[0].dtype
# Out:
# (torch.float32, torch.float32)

# %%
# exploringg some data
z = next(iter(train_dataloader))

for i in range (16):
  plt.subplot(4,4,i+1)
  plt.axis("off")
  plt.imshow(z[1][i].to(torch.uint8).detach().numpy())

# %%
z[0].dtype
# Out:
# torch.uint8

# %%
z[0].dtype
# Out:
# torch.float32

# %%
reco[0]
# Out:
# tensor([[[213.2049, 219.0001, 223.2276,  ..., 229.7455, 218.6306, 207.7406],
#          [219.4811, 236.2220, 236.8063,  ..., 222.0527, 194.5364, 186.6219],
#          [226.3889, 241.0398, 231.9200,  ..., 234.1431, 229.1865, 230.6421],
#          ...,
#          [ 64.4689,  43.8676,  30.5183,  ..., 167.7495, 228.4037, 222.8840],
#          [ 55.2963,  45.6254,  48.4555,  ..., 181.0312, 237.8358, 206.4635],
#          [ 70.7714,  91.1769, 125.5438,  ..., 147.6262, 153.8800, 104.2692]],
#
#         [[174.6280, 224.7007, 231.0247,  ..., 226.7973, 209.6270, 198.0153],
#          [225.0707, 235.1120, 237.0002,  ..., 234.8243, 208.6203, 208.2171],
#          [223.1283, 238.5080, 228.6041,  ..., 235.3181, 230.9256, 233.8371],
#          ...,
#          [ 59.0299,  46.0224,  29.8571,  ..., 166.0350, 231.5663, 224.1427],
#          [ 49.3685,  48.5255,  46.6778,  ..., 167.9712, 237.0643, 209.8403],
#          [ 89.3713,  88.4819, 120.0458,  ..., 121.8262, 156.8248, 132.7534]],
#
#         [[188.0788, 210.7455, 232.3617,  ..., 227.6274, 211.1628, 200.2005],
#          [221.2585, 235.7724, 235.2782,  ..., 233.2114, 215.0761, 200.3465],
#          [215.1310, 238.3730, 236.0242,  ..., 232.2371, 224.4005, 215.0059],
#          ...,
#          [ 59.9203,  44.9659,  32.9768,  ..., 160.8440, 223.0432, 215.4154],
#          [ 50.8193,  46.0968,  42.4270,  ..., 168.7484, 233.8425, 204.5850],
#          [ 83.7356,  89.5303, 117.2113,  ..., 157.0512, 184.4780, 105.1802]]],
#        device='cuda:0')

# %%
img[0]
# Out:
# tensor([[[252., 252., 252.,  ..., 255., 255., 255.],
#          [252., 252., 252.,  ..., 255., 255., 255.],
#          [251., 251., 251.,  ..., 255., 255., 255.],
#          ...,
#          [ 63.,  48.,  38.,  ..., 163., 251., 251.],
#          [ 59.,  48.,  56.,  ..., 164., 251., 248.],
#          [ 68.,  86., 134.,  ..., 163., 251., 244.]],
#
#         [[254., 254., 254.,  ..., 255., 255., 255.],
#          [254., 254., 254.,  ..., 255., 255., 255.],
#          [253., 253., 253.,  ..., 255., 255., 255.],
#          ...,
#          [ 68.,  53.,  43.,  ..., 168., 255., 255.],
#          [ 64.,  53.,  61.,  ..., 169., 255., 253.],
#          [ 73.,  91., 139.,  ..., 168., 255., 249.]],
#
#         [[255., 255., 255.,  ..., 255., 255., 255.],
#          [255., 255., 255.,  ..., 255., 255., 255.],
#          [254., 254., 254.,  ..., 255., 255., 255.],
#          ...,
#          [ 69.,  54.,  44.,  ..., 169., 255., 255.],
#          [ 65.,  54.,  62.,  ..., 170., 255., 252.],
#          [ 74.,  92., 140.,  ..., 169., 255., 248.]]], device='cuda:0')

# %%
# exploringg some data
z = img

for i in range (16):
  plt.subplot(4,4,i+1)
  plt.axis("off")
  plt.imshow((z[i]).to(torch.uint8).cpu().permute(1,2,0).detach().numpy())

# %%
# exploringg some data
z = reco

for i in range (16):
  plt.subplot(4,4,i+1)
  plt.axis("off")
  plt.imshow((z[i]).to(torch.uint8).cpu().permute(1,2,0).detach().numpy())

# %%
from torchmetrics.image import StructuralSimilarityIndexMeasure

ssim = StructuralSimilarityIndexMeasure(data_range=1.0)
out = ssim((reco/255.0).cpu(), (img/255.0).cpu()).item()
out
# Out:
# 0.9739878177642822

# %%
# plotting the losses
import matplotlib.pyplot as plt

# Example data
fid_values = fid_metric_list
ssim_values = ssim_metric_list
lpips_values = metric_list

# X-axis values (e.g., epochs or iteration numbers)
x_values = list(range(1, len(fid_values) + 1))

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot FID values
plt.plot(x_values, fid_values, label='FID', marker='o')

# Plot SSIM values
plt.plot(x_values, ssim_values, label='SSIM', marker='s')

# Plot LPIPS values
plt.plot(x_values, lpips_values, label='LPIPS', marker='^')

# Add labels and title
plt.xlabel('Epochs/Iterations')
plt.ylabel('Metric Values')
plt.title('FID, SSIM, and LPIPS over Time')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# plotting the losses
import matplotlib.pyplot as plt

# Example data
ssim_values = ssim_metric_list

# X-axis values (e.g., epochs or iteration numbers)
x_values = list(range(1, len(ssim_values) + 1))

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot SSIM values
plt.plot(x_values, ssim_values, label='SSIM', marker='s')

# Add labels and title
plt.xlabel('Epochs/Iterations')
plt.ylabel('Metric Values')
plt.title('SSIM over Time')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# for plotting the imgs
from zero_model import enhance_net_nopool

model_ =  torch.load("bagging_lama_mat_model.pth")
device = "cuda"
model_.to(device)
DCE_net = enhance_net_nopool().to(device)
DCE_net.load_state_dict(torch.load('Zero-DCE/Zero-DCE_code/snapshots/Epoch99.pth'))
model_.eval()
DCE_net.eval()

for i, (img, lama, mat) in enumerate(test_dataloader):
        img, lama, mat =  img.permute(0,3,1,2).to(torch.float).to(device), lama.to(torch.float).permute(0,3,1,2).to(device), mat.to(torch.float).permute(0,3,1,2).to(device)
        gt_image = img
        image_reconstructed = model_(lama, mat) # i need to do /255.0
        _,image_reconstructed2,_ = DCE_net(image_reconstructed/255.0)
        break

        # image_reconstructed = image_reconstructed*255

# %%
num = 5
plt.figure(figsize=(10,10))
plt.subplot(1,5,1)
plt.imshow(img[num].to(torch.uint8).cpu().permute(1,2,0).detach().numpy())
plt.axis("off")
plt.title("Ground Truth")

plt.subplot(1,5,2)
plt.axis("off")
plt.imshow(lama[num].cpu().to(torch.uint8).permute(1,2,0).detach().numpy())
plt.title("Lama")

plt.subplot(1,5,3)
plt.axis("off")
plt.imshow(mat[num].cpu().to(torch.uint8).permute(1,2,0).detach().numpy())
plt.title("Mat")

plt.subplot(1,5,4)
plt.axis("off")
plt.imshow(image_reconstructed[num].cpu().to(torch.uint8).permute(1,2,0).detach().numpy())
plt.title("No ZERO-DCE")

plt.subplot(1,5,5)
plt.axis("off")
plt.imshow((image_reconstructed2[num] * 255).cpu().to(torch.uint8).permute(1,2,0).detach().numpy())
plt.title("With ZERO-DCE")

# %% [markdown]
# #COLOR CORRECTION

# %%
# so till now the img is quite good the only thing needed is color correction
# 1. using SSIM LOSS
# 2. Color correction
# 3. Img harmonization
# 4.

# %%
# !pip install pytorch_ssim
# Out:
# Requirement already satisfied: pytorch_ssim in /usr/local/lib/python3.10/dist-packages (0.1)

# %%
import torch
import torch.nn.functional as F
import numpy as np

def gaussian_window(window_size, sigma):
    """Generates a 1D Gaussian window."""
    gauss = torch.Tensor([np.exp(-(x - window_size // 2) ** 2 / float(2 * sigma ** 2)) for x in range(window_size)])
    return gauss / gauss.sum()

def create_window(window_size, channel):
    """Creates a 2D Gaussian window for each channel."""
    _1D_window = gaussian_window(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = _2D_window.expand(channel, 1, window_size, window_size).contiguous()
    return window

def ssim(img1, img2, window_size=11, size_average=True, data_range=1):
    """Calculates SSIM between two images."""
    # Ensure both images are 4D tensors (N, C, H, W) and have the same shape
    if img1.shape != img2.shape:
        raise ValueError("Input images must have the same dimensions.")

    _, channel, _, _ = img1.size()

    # Create the Gaussian window
    window = create_window(window_size, channel).to(img1.device)

    # Compute the mean (mu) for both images
    mu1 = F.conv2d(img1, window, padding=window_size // 2, groups=channel)
    mu2 = F.conv2d(img2, window, padding=window_size // 2, groups=channel)

    mu1_sq = mu1 ** 2
    mu2_sq = mu2 ** 2
    mu1_mu2 = mu1 * mu2

    # Compute the variance (sigma) and covariance
    sigma1_sq = F.conv2d(img1 * img1, window, padding=window_size // 2, groups=channel) - mu1_sq
    sigma2_sq = F.conv2d(img2 * img2, window, padding=window_size // 2, groups=channel) - mu2_sq
    sigma12 = F.conv2d(img1 * img2, window, padding=window_size // 2, groups=channel) - mu1_mu2

    # Constants to stabilize the division when the denominator is small
    C1 = (0.01 * data_range) ** 2
    C2 = (0.03 * data_range) ** 2

    # Compute the SSIM map
    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))

    # Return the mean SSIM value
    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)

def combined_loss(output, target, alpha=0.5):
    # Ensure that the input tensors are float and 4D (N, C, H, W)
    if output.ndimension() != 4 or target.ndimension() != 4:
        raise ValueError("Expected 4D tensors for output and target with shape (N, C, H, W)")

    if output.dtype != torch.float32 or target.dtype != torch.float32:
        output = output.float()
        target = target.float()

    # SSIM loss
    ssim_loss = 1 - ssim(output, target)

    # L1 loss (pixel-wise difference)
    l1_loss = F.l1_loss(output, target)

    # Combine SSIM and L1 loss, with a weighting factor alpha
    combined = alpha * ssim_loss + (1 - alpha) * l1_loss

    return combined
# Out:
# tensor(0.0060)

# %%
gt.shape, pred.shape
# Out:
# (torch.Size([256, 256, 3]), torch.Size([3, 256, 256]))

# %%
ssim(pred.unsqueeze(0).to(torch.float), gt.permute(2,0,1).unsqueeze(0).to(torch.float))
# Out:
# tensor(0.9967, grad_fn=<MeanBackward0>)

# %%
from torchmetrics.image import StructuralSimilarityIndexMeasure

ssim = StructuralSimilarityIndexMeasure(data_range=1.0)
out = ssim(pred.unsqueeze(0).to(torch.float), gt.permute(2,0,1).unsqueeze(0).to(torch.float)).item()
out
# Out:
# 0.9946113228797913

# %%
combined_loss

# %%
from ColorCorrectionML import ColorCorrectionML
import cv2

img = cv2.imread('Images/img2.png')

cc = ColorCorrectionML(img, chart='Classic', illuminant='D50')

method = 'pls' # 'linear', 'lstsq', 'pls'
# for linear regression, least square regression, and partial least square regression respectively
show = True

kwargs = {
    'method': method,
    'degree': 3, # degree of polynomial
    'interactions_only': False, # only interactions terms,
    'ncomp': 10, # number of components for PLS only
    'max_iter': 5000, # max iterations for PLS only
    'white_balance_mtd': 0 # 0: no white balance, 1: learningBasedWB, 2: simpleWB, 3: grayWorldWB,
    }

M, patch_size = cc.compute_correction(
    show=show,
    **kwargs
)


# resize img by 2
# img = cv2.resize(img, (0,0), fx=0.3, fy=0.3, interpolation=cv2.INTER_AREA)

img_corr = cc.correct_img(img, show=True)
# img_corr = cc.Parallel_correct_img(img, chunks_=50000, show=True)
